# %% [markdown]
# Read FiftyDatasets/AllDatasetsInfo/AllDataSourcesInfo/Kaggle/Sato/ Viznet datasets

# %%
import pandas as pd
from datetime import datetime
import re  

DB_or_dataset = input("Insert if using Datasets (d), Database.tables (dt), the two Data Sources (ds), Kaggle Datasets (k), Kaggle Datasets to correct (kc), Sato Datasets (s), Sato Filtered (sf), Filtered Viznet Datasets (v), or Filtered Kaggle Viznet Datasets (kv): ")

print(DB_or_dataset)

if DB_or_dataset.lower() == 'd':
    print("Using Datasets")
    datasets_xlsx = pd.read_excel("FiftyDatasets.xlsx") 
    columns_xlsx = pd.read_excel("AllColumnsFromFiftyDatasets.xlsx")
    analysed_columns_file_path = 'AnalysedColumns.xlsx'     
elif DB_or_dataset.lower() == 'dt':
    print("Using Database tables")
    datasets_xlsx = pd.read_excel("AllDatasetsInfo.xlsx")
    columns_xlsx = pd.read_excel("AllColumnsInfo.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsDB.xlsx'
elif DB_or_dataset.lower() == 'ds':
    print("Using Datasets and Database tables")
    datasets_xlsx = pd.read_excel("AllDataSourcesInfo.xlsx")
    columns_xlsx = pd.read_excel("AllAttributes_andColumnsInfo.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsDS.xlsx'
elif DB_or_dataset.lower() == 'k':
    print("Using Kaggle Datasets")
    datasets_xlsx = pd.read_excel("kaggle_datasets_with_domain_and_match.xlsx")
    columns_xlsx = pd.read_excel("kaggle_headers.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsK.xlsx'
elif DB_or_dataset.lower() == 'kc':
    print("Using Kaggle Datasets Corrections")
    datasets_xlsx = pd.read_excel("kaggle_datasets_with_domain_and_match.xlsx")
    columns_xlsx = pd.read_excel("kaggle_headers_10k.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsKc.xlsx'
elif DB_or_dataset.lower() == 's':
    print("Using Sato Datasets")
    datasets_xlsx = pd.read_excel("datasets_viznet.xlsx")
    columns_xlsx = pd.read_excel("columns_sato_only.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsSato.xlsx'
elif DB_or_dataset.lower() == 'sf':
    print("Using Sato Filtered Datasets")
    datasets_xlsx = pd.read_excel("datasets_viznet.xlsx")
    columns_xlsx = pd.read_excel("filtered_columns_sato_only.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsSatoFiltered.xlsx'
elif DB_or_dataset.lower() == 'v':
    print("Using Viznet Filtered Datasets")
    datasets_xlsx = pd.read_excel("datasets_viznet.xlsx")
    columns_xlsx = pd.read_excel("filtered_columns_viznet_all.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsViznetFiltered.xlsx'
elif DB_or_dataset.lower() == 'kv':
    print("Using Kaggle Viznet Filtered Datasets")
    datasets_xlsx = pd.read_excel("kaggle_viznet_datasets.xlsx")
    columns_xlsx = pd.read_excel("filtered_kaggle_viznet_headers.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsKaggleViznetFiltered.xlsx'
elif DB_or_dataset.lower() == 'sem':
    print("Using SemTabTest 2024 terms")
    datasets_xlsx = pd.read_excel("SemTabTest2024Dataset.xlsx")
    columns_xlsx = pd.read_excel("SemTabTest2024.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsSemTabTest2024.xlsx'
elif DB_or_dataset.lower() == 'sotab':
    print("Using Sotab metadata")
    datasets_xlsx = pd.read_excel("SotabShemasDataset.xlsx")
    columns_xlsx = pd.read_excel("SotabColumns.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsSotab.xlsx'
elif DB_or_dataset.lower() == 't2dv2':
    print("Using t2dv2")
    datasets_xlsx = pd.read_excel("t2dv2Datasets.xlsx")
    columns_xlsx = pd.read_excel("t2dv2Columns.xlsx")
    analysed_columns_file_path = 'AnalysedColumnst2dv2.xlsx'
elif DB_or_dataset.lower() == 'dbp':
    print("Using DbPedia metadata")
    datasets_xlsx = pd.read_excel("DbpediaDataset.xlsx")
    columns_xlsx = pd.read_excel("DbpediaMetadataColumns.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsDbpediaMetadata.xlsx'
else:
    raise ValueError("Invalid input. Please enter 'd', 'dt', 'ds', 'k', 'kc', 's', 'sf', 'v' or 'kv'.")
# Out:
# sotab
# Using Sotab metadata

# %%
columns_xlsx = columns_xlsx.rename(columns={'index': 'dataset_index'})

columns_xlsx.head()
# Out:
#      dataset_index        name    area      Original Column  Unnamed: 4  \
# 0  Schema Property  Schema org   SOTAB      20.  areaServed         NaN
# 1  Schema Property  Schema org   SOTAB  16.  valueReference         NaN
# 2  Schema Property  Schema org   SOTAB        16.  location         NaN
# 3  Schema Property  Schema org   SOTAB        15.  keywords         NaN
# 4  Schema Property  Schema org   SOTAB        15.  category         NaN
#
#         Original   Frequency Distribution
# 0      areaServed                      20
# 1  valueReference                      16
# 2        location                      16
# 3        keywords                      15
# 4        category                      15

# %% [markdown]
# Clean Columns

# %%
import pandas as pd
import re
from datetime import datetime

def clean_columns(df: pd.DataFrame) -> pd.DataFrame:
    # 1. Extract the ID from the column name 
    df['ID'] = df['Original Column'].str.extract(r'(\d+)\.')

    # 2. Extract the Column name up to the first colon, slash, or parenthesis
    df['Column'] = df['Original Column'].str.extract(r'\d+\.\s*([^/(:]+)')

    # 3. Extract everything after the first colon, slash, or parenthesis as the full description
    df['Description'] = df['Original Column'].str.extract(r'\d+\.\s*[^/(:]+\s*[:(/](.*)')[0]

    # 4. For cases where Description is None,
    #    extract the content within parentheses
    mask = df['Description'].isnull()
    df.loc[mask, 'Description'] = df.loc[mask, 'Original Column'].str.extract(r'\(([^)]+)\)')

    # 5. Trim spaces from all string columns
    for col in df.columns:
        if df[col].dtype == "object" and col != 'dataset_index':
            df[col] = df[col].str.strip()

    # 6. Replace empty strings with pd.NA  ← changed from None to pd.NA to avoid downcasting warning
    df = df.replace(r'^\s*$', pd.NA, regex=True)
    df = df.infer_objects(copy=False)
    
    # 7. Ensure Description is object dtype before applying .str.replace  ← added to avoid incompatible dtype warning
    df['Description'] = df['Description'].astype(object)

    # 8. Only apply .str.replace on non-null Description rows,
    #    converting to string first to avoid errors
    mask_desc = df['Description'].notnull()
    df.loc[mask_desc, 'Description'] = (
        df.loc[mask_desc, 'Description']
          .astype(str)
          .str.replace(r'\(', ' ', regex=True)
          .str.replace(r'\)', '', regex=True)
    )

    # 9. Reorder columns to ensure ID comes before Column
    columns_order = ['dataset_index', 'name', 'area', 'Original Column', 'ID', 'Column', 'Description']
    columns_order = [col for col in columns_order if col in df.columns]
    df = df[columns_order]

    return df

# Test the function with a sample DataFrame
if __name__ == "__main__":
    test_df = pd.DataFrame({
        'Original Column': [
            '14. num (the predicted attribute)',
            '1. lettr: capital letter (26 values from A to Z)',
            '2. x-box: horizontal position of the box (integer)',
            '1. sepal length in cm',
            '20. Foreign worker (qualitative)',
            '12. A12: Categorical with values: t, f',
            '55. capital_run_length_average (1 continuous real attribute): Average length of uninterrupted sequences of capital letters',
            '1. Class Name (party affiliation): democrat, republican',
            '1.Sex / nominal / -- / M, F, and I (infant)',
            '3.Cell Nucleus 1 - a) radius (mean of distances from center to points on the perimeter)',
            '14. win_loc (varchar(255))',
            '33. #'
        ],
        'dataset_index': ['SATO_000001'] * 12,
        'name': [None] * 12,
        'area': ['Sato-Viznet'] * 12
    })

print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
cleaned_df = clean_columns(test_df)
cleaned_df
# Out:
# Last run on: 2025-07-08 16:21:08
#    dataset_index  name         area  \
# 0    SATO_000001  None  Sato-Viznet
# 1    SATO_000001  None  Sato-Viznet
# 2    SATO_000001  None  Sato-Viznet
# 3    SATO_000001  None  Sato-Viznet
# 4    SATO_000001  None  Sato-Viznet
# 5    SATO_000001  None  Sato-Viznet
# 6    SATO_000001  None  Sato-Viznet
# 7    SATO_000001  None  Sato-Viznet
# 8    SATO_000001  None  Sato-Viznet
# 9    SATO_000001  None  Sato-Viznet
# 10   SATO_000001  None  Sato-Viznet
# 11   SATO_000001  None  Sato-Viznet
#
#                                                                                                                Original Column  \
# 0                                                                                            14. num (the predicted attribute)
# 1                                                                             1. lettr: capital letter (26 values from A to Z)
# 2                                                                           2. x-box: horizontal position of the box (integer)
# 3                                                                                                        1. sepal length in cm
# 4                                                                                             20. Foreign worker (qualitative)
# 5                                                                                       12. A12: Categorical with values: t, f
# 6   55. capital_run_length_average (1 continuous real attribute): Average length of uninterrupted sequences of capital letters
# 7                                                                      1. Class Name (party affiliation): democrat, republican
# 8                                                                                  1.Sex / nominal / -- / M, F, and I (infant)
# 9                                      3.Cell Nucleus 1 - a) radius (mean of distances from center to points on the perimeter)
# 10                                                                                                  14. win_loc (varchar(255))
# 11                                                                                                                       33. #
#
#     ID                      Column  \
# 0   14                         num
# 1    1                       lettr
# 2    2                       x-box
# 3    1          sepal length in cm
# 4   20              Foreign worker
# 5   12                         A12
# 6   55  capital_run_length_average
# 7    1                  Class Name
# 8    1                         Sex
# 9    3  Cell Nucleus 1 - a) radius
# 10  14                     win_loc
# 11  33                           #
#
#                                                                                   Description
# 0                                                                     the predicted attribute
# 1                                                       capital letter  26 values from A to Z
# 2                                                     horizontal position of the box  integer
# 3                                                                                         NaN
# 4                                                                                 qualitative
# 5                                                               Categorical with values: t, f
# 6   1 continuous real attribute: Average length of uninterrupted sequences of capital letters
# 7                                                     party affiliation: democrat, republican
# 8                                                          nominal / -- / M, F, and I  infant
# 9                                    mean of distances from center to points on the perimeter
# 10                                                                                varchar 255
# 11                                                                                        NaN

# %% [markdown]
# Open formats and abreviations dictionaries

# %%
dictionary = {}

# Open the formats dictionary file and read line by line 
with open("formats_dictionary.txt", "r") as file:
    for line in file:
        # Remove the trailing newline and comma, then split the line into key and value at the colon
        key, value = line.rstrip(",\n").split(":")
    
        # Remove the quotes around the key and value
        key = key.strip("'").lower()
        value = value.strip("'")

        # Add the key-value pair to the dictionary
        dictionary[key] = value

# Load the abbreviations dictionary
abbreviations_dict = {}
with open("abbreviations_dictionary.txt", "r") as file:
    for line in file:
        abbr, full_form = line.strip().split(":")
        abbreviations_dict[abbr.strip().lower()] = full_form.strip()
        
print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Last run on: 2025-07-08 16:21:08

# %% [markdown]
# Replace abbreviations

# %%
def replace_abbreviations(text, abbreviations_dict):
    tokens = re.findall(
        r'\b\w+(?:[-=]\w+)*\b'          # Words, with hyphens/equals (like 0-4, 1=NE)
        r'|[=]'                         # Standalone equal signs
        r'|[°º][CFK]'                   # °C, ºF, etc.
        r'|[°º\-]+'                     # Standalone degree/hyphens
        r'|[a-zA-Z]+/[a-zA-Z]+(?:[²³μµ]?)'   # mg/dL, kg/m², µg/m³, cm², etc.
        r'|\d+[²³]?'                    # 10², 5³ (numbers with superscripts)
        r'|%'                           # <- add this line to capture % as a token
        , text
    )
    replaced_tokens = [abbreviations_dict.get(token.lower(), token) for token in tokens]
    return " ".join(replaced_tokens)

target_words_dict = dictionary
description_words_dict = dictionary

test_df = pd.DataFrame({
    "Original Column": [
        "1. chlorides (mg/dL)",                # plural with unit
        "2. chloride (mg/dL)",                 # singular with unit
        "3. Fuel_Price (USD/L)",               # phrase with underscore, unit
        "4. Tumor-size: 0-4, 5-9, 10-14",      # category ranges with hyphens
        "5. zone: 1=NE, 2=SE, 3=SW, 4=NW",     # code marker with equals
        "6. temperature (°C)",                 # temperature symbol
        "7. temperature (ºF)",                 # alternate degree symbol
        "8. Tdewpoint (from Chievres weather station), °C", # degree symbol at end
        "9. cm² measurement",                  # superscript unit
        "10. workclass",                       # compound word
        "11. landmass",                        # compound word
        "12. thickness (mm³)",                 # unit with superscript ³
        "13. concentration: 5mg/dL",           # value with unit
        "14. value: 10cm³",                    # value with unit
        "15. intensity: 5³, 10²",              # numeric with superscripts
        "16. 0-1 category",                    # hyphen, short
        "17. 1=Red, 2=Blue, 3=Green",          # equals for codes
        "18. percent (%)",                     # symbol in column
        "19. velocity (km/h)",                 # unit with slash
        "20. area: 10cm2, 10cm³",              # unit, no symbol and symbol
        "21. Alcohol (%)",                     # percent
        "22. BMI (kg/m²)",                     # slash, superscript
        "23. air_quality_index (AQI)",         # abbreviation as token
        "24. mean-pH",                         # hyphen in column name
    ]
})

# Apply the abbreviation/tokenizer function to every row
test_df['AbbrExpanded'] = test_df['Original Column'].apply(lambda x: replace_abbreviations(str(x), abbreviations_dict))

# Display original and processed columns side by side for easy comparison
pd.set_option('display.max_colwidth', 200)
test_df[['Original Column', 'AbbrExpanded']]

#print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
#                                      Original Column  \
# 0                               1. chlorides (mg/dL)
# 1                                2. chloride (mg/dL)
# 2                              3. Fuel_Price (USD/L)
# 3                     4. Tumor-size: 0-4, 5-9, 10-14
# 4                    5. zone: 1=NE, 2=SE, 3=SW, 4=NW
# 5                                6. temperature (°C)
# 6                                7. temperature (ºF)
# 7   8. Tdewpoint (from Chievres weather station), °C
# 8                                 9. cm² measurement
# 9                                      10. workclass
# 10                                      11. landmass
# 11                               12. thickness (mm³)
# 12                         13. concentration: 5mg/dL
# 13                                  14. value: 10cm³
# 14                            15. intensity: 5³, 10²
# 15                                  16. 0-1 category
# 16                        17. 1=Red, 2=Blue, 3=Green
# 17                                   18. percent (%)
# 18                               19. velocity (km/h)
# 19                            20. area: 10cm2, 10cm³
# 20                                   21. Alcohol (%)
# 21                                   22. BMI (kg/m²)
# 22                       23. air_quality_index (AQI)
# 23                                       24. mean-pH
#
#                                     AbbrExpanded
# 0                              1 chlorides mg dL
# 1                               2 chloride mg dL
# 2                        3 Fuel_Price USD losses
# 3                     4 Tumor-size 0-4 5-9 10-14
# 4                     5 zone 1=NE 2=SE 3=SW 4=NW
# 5                               6 temperature °C
# 6                               7 temperature ºF
# 7   8 Tdewpoint from Chievres weather station °C
# 8                              9 cm² measurement
# 9                                   10 workclass
# 10                                   11 landmass
# 11                              12 thickness mm³
# 12                       13 concentration 5mg dL
# 13                                14 value 10cm³
# 14                           15 intensity 5³ 10²
# 15                               16 0-1 category
# 16                       17 1=Red 2=Blue 3=Green
# 17                                  18 percent %
# 18                           19 velocity km hits
# 19                           20 area 10cm2 10cm³
# 20                                  21 Alcohol %
# 21                      22 body mass index kg m²
# 22                      23 air_quality_index AQI
# 23                                    24 mean-pH

# %% [markdown]
# Split Camel Case

# %%
import re

def split_camel_case(s):
    if s.lower() == 'ph':
        return 'ph'
    # Split on separators
    tokens = re.split(r'[\s._\-]+', s)
    processed_tokens = []

    for token in tokens:
        if not token:
            continue
        # If all uppercase or digits, keep as is
        if token.isupper() or token.isdigit():
            processed_tokens.append(token.lower())
            continue
        # If all-uppercase+digits, keep as is
        if re.match(r'^[A-Z]{2,}\d+$', token):
            processed_tokens.append(token.lower())
            continue

        # Character-by-character scan
        words = []
        current = ''
        i = 0
        while i < len(token):
            c = token[i]
            if current == '':
                current = c
            elif (
                # lower->upper transition
                (current[-1].islower() and c.isupper()) or
                # digit->letter or letter->digit
                (current[-1].isdigit() and c.isalpha()) or
                (current[-1].isalpha() and c.isdigit())
            ):
                words.append(current)
                current = c
            else:
                current += c
            i += 1
        if current:
            words.append(current)

        # Now check if the last two or more are all caps: join them!
        if len(words) >= 2 and all(w.isupper() for w in words[-2:]) and len(''.join(words[-2:])) >= 2:
            # Join last all-cap runs
            n = len(words) - 1
            while n > 0 and words[n].isupper():
                n -= 1
            # All uppercase words from n+1 to end are the tail
            head = words[:n+1]
            tail = ''.join(words[n+1:])
            processed_tokens.extend([w.lower() for w in head if w])
            if tail:
                processed_tokens.append(tail.lower())
        else:
            processed_tokens.extend([w.lower() for w in words if w])

    return ' '.join(processed_tokens)

print(split_camel_case("reviews.sourceURLs"))   # reviews source urls
print(split_camel_case("prices.sourceURLs"))    # prices source urls
print(split_camel_case("sourceURLs"))           # source urls
print(split_camel_case("UrlLength"))            # url length
print(split_camel_case("nation_flag_url"))      # nation flag url
print(split_camel_case("URLs"))              # mean ph
print(split_camel_case("JSONFileURL"))          # json file url
print(split_camel_case("ODIDs"))                # odids
print(split_camel_case("ODID"))                # odid
# Out:
# reviews source urls
# prices source urls
# source urls
# url length
# nation flag url
# urls
# jsonfile url
# odids
# odid

# %%
columns_xlsx
# Out:
#             dataset_index        name    area                 Original Column  \
# 0         Schema Property  Schema org   SOTAB                 20.  areaServed
# 1         Schema Property  Schema org   SOTAB             16.  valueReference
# 2         Schema Property  Schema org   SOTAB                   16.  location
# 3         Schema Property  Schema org   SOTAB                   15.  keywords
# 4         Schema Property  Schema org   SOTAB                   15.  category
# ..                    ...         ...     ...                             ...
# 732  Schema expected_type  Schema org   SOTAB  1.  MonetaryAmountDistribution
# 733  Schema expected_type  Schema org   SOTAB           1.  ItemListOrderType
# 734  Schema expected_type  Schema org   SOTAB                     1.  WebSite
# 735  Schema expected_type  Schema org   SOTAB         1.  SoftwareApplication
# 736  Schema expected_type  Schema org   SOTAB                  1.  TextObject
#
#      Unnamed: 4                   Original   Frequency Distribution
# 0           NaN                  areaServed                      20
# 1           NaN              valueReference                      16
# 2           NaN                    location                      16
# 3           NaN                    keywords                      15
# 4           NaN                    category                      15
# ..          ...                         ...                     ...
# 732         NaN  MonetaryAmountDistribution                       1
# 733         NaN           ItemListOrderType                       1
# 734         NaN                     WebSite                       1
# 735         NaN         SoftwareApplication                       1
# 736         NaN                  TextObject                       1
#
# [737 rows x 7 columns]

# %%
cleaned_columns_df = clean_columns(columns_xlsx.copy())
cleaned_columns_df
# Out:
# C:\Users\290099c\AppData\Local\Temp\ipykernel_29456\217142845.py:26: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(r'^\s*$', pd.NA, regex=True)
#             dataset_index        name   area                 Original Column  \
# 0         Schema Property  Schema org  SOTAB                 20.  areaServed
# 1         Schema Property  Schema org  SOTAB             16.  valueReference
# 2         Schema Property  Schema org  SOTAB                   16.  location
# 3         Schema Property  Schema org  SOTAB                   15.  keywords
# 4         Schema Property  Schema org  SOTAB                   15.  category
# ..                    ...         ...    ...                             ...
# 732  Schema expected_type  Schema org  SOTAB  1.  MonetaryAmountDistribution
# 733  Schema expected_type  Schema org  SOTAB           1.  ItemListOrderType
# 734  Schema expected_type  Schema org  SOTAB                     1.  WebSite
# 735  Schema expected_type  Schema org  SOTAB         1.  SoftwareApplication
# 736  Schema expected_type  Schema org  SOTAB                  1.  TextObject
#
#      ID                      Column Description
# 0    20                  areaServed         NaN
# 1    16              valueReference         NaN
# 2    16                    location         NaN
# 3    15                    keywords         NaN
# 4    15                    category         NaN
# ..   ..                         ...         ...
# 732   1  MonetaryAmountDistribution         NaN
# 733   1           ItemListOrderType         NaN
# 734   1                     WebSite         NaN
# 735   1         SoftwareApplication         NaN
# 736   1                  TextObject         NaN
#
# [737 rows x 7 columns]

# %% [markdown]
# Preprocess Columns

# %%
def preprocess_columns(df):
        
    # Only convert "Column" to string type for non-null values and then to lowercase to create "CleanedColumn"
    mask = df['Column'].notna()

    df.loc[mask, 'Column'] = df.loc[mask, 'Column'].str.replace('#', 'number', regex=False)
    
    df.loc[mask, 'CleanedColumn'] = df.loc[mask, 'Column'].astype(str).apply(split_camel_case)
    
    # Remove '-' and '_' characters only for non-null values
    mask = df['CleanedColumn'].notna()
    df.loc[mask, 'CleanedColumn'] = df.loc[mask, 'CleanedColumn'].str.replace('[-_]', ' ', regex=True)

    # Apply abbreviations dictionary to Description
    mask = df['Description'].notna()
    df.loc[mask, 'Description'] = df.loc[mask, 'Description'].apply(lambda x: replace_abbreviations(x, abbreviations_dict))
 
    return df

# Clean the columns

cleaned_columns_df = clean_columns(columns_xlsx.copy())

# Preprocess the column names
preprocessed_columns_df = preprocess_columns(cleaned_columns_df)
print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

preprocessed_columns_df
# Out:
# Last run on: 2025-07-08 16:21:08
# C:\Users\290099c\AppData\Local\Temp\ipykernel_29456\217142845.py:26: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(r'^\s*$', pd.NA, regex=True)
#             dataset_index        name   area                 Original Column  \
# 0         Schema Property  Schema org  SOTAB                 20.  areaServed
# 1         Schema Property  Schema org  SOTAB             16.  valueReference
# 2         Schema Property  Schema org  SOTAB                   16.  location
# 3         Schema Property  Schema org  SOTAB                   15.  keywords
# 4         Schema Property  Schema org  SOTAB                   15.  category
# ..                    ...         ...    ...                             ...
# 732  Schema expected_type  Schema org  SOTAB  1.  MonetaryAmountDistribution
# 733  Schema expected_type  Schema org  SOTAB           1.  ItemListOrderType
# 734  Schema expected_type  Schema org  SOTAB                     1.  WebSite
# 735  Schema expected_type  Schema org  SOTAB         1.  SoftwareApplication
# 736  Schema expected_type  Schema org  SOTAB                  1.  TextObject
#
#      ID                      Column Description                 CleanedColumn
# 0    20                  areaServed         NaN                   area served
# 1    16              valueReference         NaN               value reference
# 2    16                    location         NaN                      location
# 3    15                    keywords         NaN                      keywords
# 4    15                    category         NaN                      category
# ..   ..                         ...         ...                           ...
# 732   1  MonetaryAmountDistribution         NaN  monetary amount distribution
# 733   1           ItemListOrderType         NaN          item list order type
# 734   1                     WebSite         NaN                      web site
# 735   1         SoftwareApplication         NaN          software application
# 736   1                  TextObject         NaN                   text object
#
# [737 rows x 8 columns]

# %% [markdown]
# KG Matching

# %%
import pandas as pd
import difflib
import numpy as np
from gensim.models.fasttext import load_facebook_vectors

# Load DBpedia and Schema.org ontology terms from your provided files
dbpedia_terms_df = pd.read_excel('dbpedia.xlsx')
dbpedia_labels = dbpedia_terms_df['cleaned_label'].astype(str).str.lower().tolist()
dbpedia_ids = dbpedia_terms_df['id'].astype(str).tolist()
dbpedia_label_to_id = dict(zip(dbpedia_labels, dbpedia_ids))

schema_terms_df = pd.read_excel('schema.xlsx')
schema_labels = schema_terms_df['cleaned_label'].astype(str).str.lower().tolist()
schema_ids = schema_terms_df['id'].astype(str).tolist()
schema_label_to_id = dict(zip(schema_labels, schema_ids))

print("Loaded DBpedia labels:", dbpedia_labels[:5], "...")
print("DBpedia label to id (sample):", {k: dbpedia_label_to_id[k] for k in dbpedia_labels[:3]})

print("Loaded Schema.org labels:", schema_labels[:5], "...")
print("Schema.org label to id (sample):", {k: schema_label_to_id[k] for k in schema_labels[:3]})

def syntactic_match(header, labels_list, label_to_id, threshold=0.9):
    header = header.strip().lower()
    if header in label_to_id:
        return label_to_id[header]
    matches = difflib.get_close_matches(header, labels_list, n=1, cutoff=threshold)
    if matches:
        return label_to_id[matches[0]]
    return None

# Load Gensim FastText model
fasttext_model = load_facebook_vectors('cc.en.300.bin')  # Update with the path to your file

print("Gensim FastText model loaded. Dimension:", fasttext_model.vector_size)

def get_embedding(text):
    words = text.split()
    vectors = [fasttext_model[w] for w in words if w in fasttext_model]
    if not vectors:
        return np.zeros(fasttext_model.vector_size)
    return np.mean(vectors, axis=0)

print("Embedding for 'birth date':", get_embedding("birth date")[:5])  # show first 5 numbers for brevity

def semantic_match(header, labels_list, label_to_id, embeddings_dict, similarity_threshold=0.9):
    header_emb = get_embedding(header)
    best_sim = -1
    best_label = None
    for label, emb in embeddings_dict.items():
        sim = np.dot(header_emb, emb) / (np.linalg.norm(header_emb) * np.linalg.norm(emb) + 1e-8)
        if sim > best_sim:
            best_sim = sim
            best_label = label
    if best_sim >= similarity_threshold:
        return label_to_id[best_label], best_sim
    return None, best_sim

# Precompute embeddings for ontology terms (can take a minute for large lists)
dbpedia_embeddings = {label: get_embedding(label) for label in dbpedia_labels}
schema_embeddings = {label: get_embedding(label) for label in schema_labels}

print("Sample DBpedia label embedding shape:", dbpedia_embeddings[dbpedia_labels[0]].shape)
print("First 5 dims of first embedding:", dbpedia_embeddings[dbpedia_labels[0]][:5])

# Try with some typical headers
test_headers = ['birth date', 'organization', 'assets', 'zip code', 'unknownfield']

for th in test_headers:
    result = syntactic_match(th, dbpedia_labels, dbpedia_label_to_id)
    print(f"Syntactic match (DBpedia) for '{th}':", result)
    result = syntactic_match(th, schema_labels, schema_label_to_id)
    print(f"Syntactic match (Schema.org) for '{th}':", result)

# Pick a header that may not match exactly but should semantically (abbreviations etc.)
sem_headers = ['assets', 'amt', 'org unit', 'unknownfield']

for sh in sem_headers:
    result = semantic_match(sh, dbpedia_labels, dbpedia_label_to_id, dbpedia_embeddings)
    print(f"Semantic match (DBpedia) for '{sh}':", result)
    result = semantic_match(sh, schema_labels, schema_label_to_id, schema_embeddings)
    print(f"Semantic match (Schema.org) for '{sh}':", result)
# Out:
# Loaded DBpedia labels: ['a side', 'abbeychurch blessing', 'abbeychurch blessing charge', 'abbreviation', 'able to grind'] ...
# DBpedia label to id (sample): {'a side': 'http://dbpedia.org/ontology/aSide', 'abbeychurch blessing': 'http://dbpedia.org/ontology/abbeychurchBlessing', 'abbeychurch blessing charge': 'http://dbpedia.org/ontology/abbeychurchBlessingCharge'}
# Loaded Schema.org labels: ['3 d model', 'abdomen', 'about', 'about page', 'abridged'] ...
# Schema.org label to id (sample): {'3 d model': 'https://schema.org/3DModel', 'abdomen': 'https://schema.org/Abdomen', 'about': 'https://schema.org/about'}
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[97], line 33
#      30     return None
#      32 # Load Gensim FastText model
# ---> 33 fasttext_model = load_facebook_vectors('cc.en.300.bin')  # Update with the path to your file
#      35 print("Gensim FastText model loaded. Dimension:", fasttext_model.vector_size)
#      37 def get_embedding(text):
#
# File c:\Users\290099c\AppData\Local\anaconda3\Lib\site-packages\gensim\models\fasttext.py:784, in load_facebook_vectors(path, encoding)
#     731 def load_facebook_vectors(path, encoding='utf-8'):
#     732     """Load word embeddings from a model saved in Facebook's native fasttext `.bin` format.
#     733
#     734     Notes
#    (...)
#     782
#     783     """
# --> 784     full_model = _load_fasttext_format(path, encoding=encoding, full_model=False)
#     785     return full_model.wv
#
# File c:\Users\290099c\AppData\Local\anaconda3\Lib\site-packages\gensim\models\fasttext.py:808, in _load_fasttext_format(model_file, encoding, full_model)
#     789 """Load the input-hidden weight matrix from Facebook's native fasttext `.bin` output files.
#     790
#     791 Parameters
#    (...)
#     805
#     806 """
#     807 with utils.open(model_file, 'rb') as fin:
# --> 808     m = gensim.models._fasttext_bin.load(fin, encoding=encoding, full_model=full_model)
#     810 model = FastText(
#     811     vector_size=m.dim,
#     812     window=m.ws,
#    (...)
#     821     max_n=m.maxn,
#     822 )
#     823 model.corpus_total_words = m.ntokens
#
# File c:\Users\290099c\AppData\Local\anaconda3\Lib\site-packages\gensim\models\_fasttext_bin.py:348, in load(fin, encoding, full_model)
#     345 raw_vocab, vocab_size, nwords, ntokens = _load_vocab(fin, new_format, encoding=encoding)
#     346 model.update(raw_vocab=raw_vocab, vocab_size=vocab_size, nwords=nwords, ntokens=ntokens)
# --> 348 vectors_ngrams = _load_matrix(fin, new_format=new_format)
#     350 if not full_model:
#     351     hidden_output = None
#
# File c:\Users\290099c\AppData\Local\anaconda3\Lib\site-packages\gensim\models\_fasttext_bin.py:282, in _load_matrix(fin, new_format)
#     280     matrix = _fromfile(fin, _FLOAT_DTYPE, count)
#     281 else:
# --> 282     matrix = np.fromfile(fin, _FLOAT_DTYPE, count)
#     284 assert matrix.shape == (count,), 'expected (%r,),  got %r' % (count, matrix.shape)
#     285 matrix = matrix.reshape((num_vectors, dim))
#
# MemoryError: Unable to allocate 4.47 GiB for an array with shape (1200000000,) and data type float32

# %% [markdown]
# Apply analysis

# %%
import pandas as pd
import re

def match_with_plural(token, dictionary):
    # Attempt direct match first
    if token in dictionary:
        return dictionary[token]
    # Check for 'ies' -> 'y' (families -> family)
    if token.endswith('ies') and len(token) > 3:
        singular = token[:-3] + 'y'
        if singular in dictionary:
            return dictionary[singular]
    # Check for 'es' -> '' (e.g., classes -> class)
    if token.endswith('es') and len(token) > 2:
        singular = token[:-2]
        if singular in dictionary:
            return dictionary[singular]
    # Check for 's' -> '' (e.g., chlorides -> chloride)
    if token.endswith('s') and len(token) > 2:
        singular = token[:-1]
        if singular in dictionary:
            return dictionary[singular]
    return None

def apply_analysis(df, target_words_dict, description_words_dict, abbreviations_dict, all_datasets_info):

    def get_special_name_format(table_name, column_name):
        special_cases = {
            'city': 'city',
            'country': 'country',
            'state': 'state',
            'province': 'state'  # province is treated as state
        }
        
        if DB_or_dataset.lower() == 'd':
            # For datasets, table_name is a number, so we don't check it
            if column_name.lower() == 'name':
                return 'name', target_words_dict['name']
        else:
            # For database tables, check if any special case is in the table name
            table_name_str = str(table_name).lower()
            for case, format_type in special_cases.items():
                if case in table_name_str and column_name.lower() == 'name':
                    return f"{format_type}_name", target_words_dict[format_type]
        
        return 'name', target_words_dict['name']
    
    # main code 
    # Check if PK/FK information is available
    has_pk_fk_info = 'primary_key' in all_datasets_info.columns and 'foreign_keys' in all_datasets_info.columns

    # Get primary and foreign keys for each table
    pk_fk_dict = {}
    if has_pk_fk_info:
        for _, row in all_datasets_info.iterrows():
            table_name = row['index']
            pk = row['primary_key'] if pd.notna(row['primary_key']) else None
            fks = row['foreign_keys'].split(', ') if pd.notna(row['foreign_keys']) else []
            fk_columns = [fk.split(' -> ')[0] for fk in fks]
            pk_fk_dict[table_name] = {'pk': pk, 'fks': fk_columns} 

    # 'formats_ordered_list' is a list of dictionary keys in the order they appear in 'formats_dictionary'
    formats_ordered_list = list(target_words_dict.keys())

    # Initialize new columns
    df['ColumnKeyword'] = None
    df['ColumnFormat'] = None
    df['DescriptionKeyword'] = None
    df['DescriptionFormat'] = None
    count = 0
   
    # Apply target words analysis
    for i, row in df.iterrows():
        count += 1
        if count % 1000 == 0:
            print(f"✅ Processed {count} rows...")

        std_col_name = row['CleanedColumn']
        col_name = row['Column']
        table_name = row['dataset_index']

        # Skip if 'CleanedColumn' is missing
        if pd.isnull(std_col_name):
            continue

        # Split camel case
        std_col_name = split_camel_case(std_col_name)

        # Check if the column is a primary key or foreign key
        if table_name in pk_fk_dict:
            if col_name == pk_fk_dict[table_name]['pk'] or col_name in pk_fk_dict[table_name]['fks']:
                df.at[i, 'ColumnKeyword'] = 'id'
                df.at[i, 'ColumnFormat'] = 'IDcolumn'
                continue

        found = False

        # Iterate through each word based on the order in 'formats_ordered_list'
        for word in formats_ordered_list:
            analysis = target_words_dict[word.lower()]
            # Special handling for 'name'
            if word == 'name':
                keyword, format_type = get_special_name_format(table_name, col_name)
                if keyword != 'name':
                    df.at[i, 'ColumnKeyword'] = keyword
                    df.at[i, 'ColumnFormat'] = format_type
                    found = True
                    break
                pattern = rf'({word})(?![\\w-])'
            # Special handling for uppercase 'ID' at the end of a column name
            elif word == 'id' and col_name.endswith('ID'):
                df.at[i, 'ColumnKeyword'] = 'id'
                df.at[i, 'ColumnFormat'] = target_words_dict.get('id', 'ID column')
                found = True
                break
            else:
                # General matching for other terms
                pattern = rf'\b{word}\b'

            # Search for the pattern in the CleanedColumn
            if re.search(pattern, std_col_name, re.IGNORECASE):
                df.at[i, 'ColumnKeyword'] = word
                df.at[i, 'ColumnFormat'] = analysis
                found = True
                break

        # If no match found, replace abbreviations and try again
        if not found:
            replaced_text = replace_abbreviations(std_col_name, abbreviations_dict)
            for word in formats_ordered_list:
                pattern = rf'\b{word}\b'
                if re.search(pattern, replaced_text, re.IGNORECASE):
                    df.at[i, 'ColumnKeyword'] = word
                    df.at[i, 'ColumnFormat'] = target_words_dict[word.lower()]
                    found = True
                    break


        # If still no match, check tokens only
        if not found:
            tokens = re.findall(r'\b\w+\b|%', row['CleanedColumn'].lower())
            for token in tokens:
                expanded_token = abbreviations_dict.get(token.lower(), None)
                # First check plural support for expanded_token
                if expanded_token:
                    match = match_with_plural(expanded_token, target_words_dict)
                    if match:
                        df.at[i, 'ColumnKeyword'] = expanded_token
                        df.at[i, 'ColumnFormat'] = match
                        found = True
                        break
                # Then check plural support for the token itself
                match = match_with_plural(token, target_words_dict)
                if match:
                    df.at[i, 'ColumnKeyword'] = token
                    df.at[i, 'ColumnFormat'] = match
                    found = True
                    break

        # -- PRIORITIZE percentage if % present in CleanedColumn tokens --
        tokens = re.findall(r'\b\w+\b|%', row['CleanedColumn'].lower())
        if '%' in tokens and '%' in target_words_dict:
            df.at[i, 'ColumnKeyword'] = '%'
            df.at[i, 'ColumnFormat'] = target_words_dict['%']

    count = 0
    # Apply description words analysis
    for i, row in df.iterrows():
        count += 1
        if count % 1000 == 0:
            print(f"✅ Processed {count} rows...")
        # Skip if 'Description' is missing
        if pd.isnull(row['Description']):
            continue
        for word, analysis in description_words_dict.items():
            if word in ['is', 'has']:
                pattern = r'^\s*' + re.escape(word) + r'\b'
                if re.search(pattern, row['Description'], re.IGNORECASE):
                    df.at[i, 'DescriptionKeyword'] = word
                    df.at[i, 'DescriptionFormat'] = analysis
                    break
            else:
                if re.search(rf'\b{re.escape(word)}\b', row['Description'], re.IGNORECASE):
                    df.at[i, 'DescriptionKeyword'] = word
                    df.at[i, 'DescriptionFormat'] = analysis
                    break
                elif not word.isalnum():
                    if word.lower() in row['Description'].lower():
                        df.at[i, 'DescriptionKeyword'] = word
                        df.at[i, 'DescriptionFormat'] = analysis
                        break

    return df

# Apply this function to the dataframe
analysed_columns_df = apply_analysis(preprocessed_columns_df.copy(), target_words_dict, description_words_dict, abbreviations_dict, datasets_xlsx)


def match_with_ontology(
    header, labels_list, label_to_id, embeddings_dict,
    syntactic_thresh=0.9, semantic_thresh=0.7, column_keyword=None
):
    header_lc = header.lower().strip()

    # 1. Syntactic (exact) match
    match_id = syntactic_match(header_lc, labels_list, label_to_id, threshold=syntactic_thresh)
    if match_id:
        return match_id, 1.0

    # 2. Substring preference (force this to happen BEFORE semantic!)
    substr_matches = [label for label in labels_list if label in header_lc and len(label) >= 4]
    if substr_matches:
        substr_matches = sorted(
            substr_matches,
            key=lambda x: (len(x.split()), len(x)),  # more words, then longer
            reverse=True
        )
        best_label = substr_matches[0]
        print(f"[Substring wins] '{best_label}' in '{header}'")
        return label_to_id[best_label], 1.0

    # 3. Semantic match
    match_id, sim_score = semantic_match(header_lc, labels_list, label_to_id, embeddings_dict, similarity_threshold=semantic_thresh)
    if match_id:
        return match_id, sim_score

    # 4. ColumnKeyword
    if column_keyword:
        ck = column_keyword.lower().strip()
        match_id = syntactic_match(ck, labels_list, label_to_id, threshold=syntactic_thresh)
        if match_id:
            return match_id, 1.0
        match_id, sim_score_ck = semantic_match(ck, labels_list, label_to_id, embeddings_dict, similarity_threshold=semantic_thresh)
        if match_id:
            return match_id, sim_score_ck

    return "Nil", 0.0


def annotate_all_kgs(df, syntactic_thresh=0.9, semantic_thresh=0.75):
    def kg_annotate_row(row, labels_list, label_to_id, embeddings_dict):
        return match_with_ontology(
            str(row['CleanedColumn']),
            labels_list, label_to_id, embeddings_dict,
            syntactic_thresh, semantic_thresh,
            column_keyword=row.get('ColumnKeyword', None)
        )

    db_results = df.apply(
        lambda row: kg_annotate_row(row, dbpedia_labels, dbpedia_label_to_id, dbpedia_embeddings),
        axis=1
    )
    df['DBpediaType'] = [r[0] for r in db_results]
    df['DBpediaScore'] = [r[1] for r in db_results]

    schema_results = df.apply(
        lambda row: kg_annotate_row(row, schema_labels, schema_label_to_id, schema_embeddings),
        axis=1
    )
    df['SchemaOrgType'] = [r[0] for r in schema_results]
    df['SchemaScore'] = [r[1] for r in schema_results]

    return df


analysed_columns_df['ColumnDescCombined'] = (
    analysed_columns_df['CleanedColumn'].fillna('').astype(str) + ' ' +
    analysed_columns_df['Description'].fillna('').astype(str)
)

analysed_columns_df = annotate_all_kgs(analysed_columns_df, syntactic_thresh=1.0)

# Preview results
ac = analysed_columns_df[['CleanedColumn', 'Description', 'DBpediaType', 'DBpediaScore', 'SchemaOrgType', 'SchemaScore']].head(60)

print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

ac
# Out:
# ✅ Processed 1000 rows...
# ✅ Processed 2000 rows...
# ✅ Processed 3000 rows...
# ✅ Processed 4000 rows...
# ✅ Processed 5000 rows...
# ✅ Processed 6000 rows...
# ✅ Processed 7000 rows...
# ✅ Processed 8000 rows...
# ✅ Processed 9000 rows...
# ✅ Processed 10000 rows...
# ✅ Processed 11000 rows...
# ✅ Processed 12000 rows...
# ✅ Processed 13000 rows...
# ✅ Processed 14000 rows...
# ✅ Processed 15000 rows...
# ✅ Processed 16000 rows...
# ✅ Processed 17000 rows...
# ✅ Processed 18000 rows...
# ✅ Processed 19000 rows...
# ✅ Processed 20000 rows...
# ✅ Processed 21000 rows...
# ✅ Processed 22000 rows...
# ✅ Processed 23000 rows...
# ✅ Processed 24000 rows...
# ✅ Processed 25000 rows...
# ✅ Processed 26000 rows...
# ✅ Processed 27000 rows...
# ✅ Processed 28000 rows...
# ✅ Processed 29000 rows...
# ✅ Processed 30000 rows...
# ✅ Processed 31000 rows...
# ✅ Processed 32000 rows...
# ✅ Processed 33000 rows...
# ✅ Processed 34000 rows...
# ✅ Processed 35000 rows...
# ✅ Processed 36000 rows...
# ✅ Processed 37000 rows...
# ✅ Processed 38000 rows...
# ✅ Processed 39000 rows...
# ✅ Processed 40000 rows...
# ✅ Processed 41000 rows...
# ✅ Processed 42000 rows...
# ✅ Processed 43000 rows...
# ✅ Processed 44000 rows...
# ✅ Processed 45000 rows...
# ✅ Processed 46000 rows...
# ✅ Processed 47000 rows...
# ✅ Processed 48000 rows...
# ✅ Processed 49000 rows...
# ✅ Processed 50000 rows...
# ✅ Processed 51000 rows...
# ✅ Processed 52000 rows...
# ✅ Processed 53000 rows...
# ✅ Processed 54000 rows...
# ✅ Processed 55000 rows...
# ✅ Processed 56000 rows...
# ✅ Processed 57000 rows...
# ✅ Processed 58000 rows...
# ✅ Processed 59000 rows...
# ✅ Processed 60000 rows...
# ✅ Processed 61000 rows...
# ✅ Processed 62000 rows...
# ✅ Processed 63000 rows...
# ✅ Processed 64000 rows...
# ✅ Processed 65000 rows...
# ✅ Processed 66000 rows...
# ✅ Processed 67000 rows...
# ✅ Processed 68000 rows...
# ✅ Processed 69000 rows...
# ✅ Processed 70000 rows...
# ✅ Processed 71000 rows...
# ✅ Processed 72000 rows...
# ✅ Processed 73000 rows...
# ✅ Processed 74000 rows...
# ✅ Processed 1000 rows...
# ✅ Processed 2000 rows...
# ✅ Processed 3000 rows...
# ✅ Processed 4000 rows...
# ✅ Processed 5000 rows...
# ✅ Processed 6000 rows...
# ✅ Processed 7000 rows...
# ✅ Processed 8000 rows...
# ✅ Processed 9000 rows...
# ✅ Processed 10000 rows...
# ✅ Processed 11000 rows...
# ✅ Processed 12000 rows...
# ✅ Processed 13000 rows...
# ✅ Processed 14000 rows...
# ✅ Processed 15000 rows...
# ✅ Processed 16000 rows...
# ✅ Processed 17000 rows...
# ✅ Processed 18000 rows...
# ✅ Processed 19000 rows...
# ✅ Processed 20000 rows...
# ✅ Processed 21000 rows...
# ✅ Processed 22000 rows...
# ✅ Processed 23000 rows...
# ✅ Processed 24000 rows...
# ✅ Processed 25000 rows...
# ✅ Processed 26000 rows...
# ✅ Processed 27000 rows...
# ✅ Processed 28000 rows...
# ✅ Processed 29000 rows...
# ✅ Processed 30000 rows...
# ✅ Processed 31000 rows...
# ✅ Processed 32000 rows...
# ✅ Processed 33000 rows...
# ✅ Processed 34000 rows...
# ✅ Processed 35000 rows...
# ✅ Processed 36000 rows...
# ✅ Processed 37000 rows...
# ✅ Processed 38000 rows...
# ✅ Processed 39000 rows...
# ✅ Processed 40000 rows...
# ✅ Processed 41000 rows...
# ✅ Processed 42000 rows...
# ✅ Processed 43000 rows...
# ✅ Processed 44000 rows...
# ✅ Processed 45000 rows...
# ✅ Processed 46000 rows...
# ✅ Processed 47000 rows...
# ✅ Processed 48000 rows...
# ✅ Processed 49000 rows...
# ✅ Processed 50000 rows...
# ✅ Processed 51000 rows...
# ✅ Processed 52000 rows...
# ✅ Processed 53000 rows...
# ✅ Processed 54000 rows...
# ✅ Processed 55000 rows...
# ✅ Processed 56000 rows...
# ✅ Processed 57000 rows...
# ✅ Processed 58000 rows...
# ✅ Processed 59000 rows...
# ✅ Processed 60000 rows...
# ✅ Processed 61000 rows...
# ✅ Processed 62000 rows...
# ✅ Processed 63000 rows...
# ✅ Processed 64000 rows...
# ✅ Processed 65000 rows...
# ✅ Processed 66000 rows...
# ✅ Processed 67000 rows...
# ✅ Processed 68000 rows...
# ✅ Processed 69000 rows...
# ✅ Processed 70000 rows...
# ✅ Processed 71000 rows...
# ✅ Processed 72000 rows...
# ✅ Processed 73000 rows...
# ✅ Processed 74000 rows...
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'course' in 'courses'
# [Substring wins] 'area' in 'expertise areas'
# [Substring wins] 'date' in 'expires date'
# [Substring wins] 'type' in 'biotype'
# [Substring wins] 'flag' in 'flags'
# [Substring wins] 'airline' in 'airlines'
# [Substring wins] 'number' in 'patent application number'
# [Substring wins] 'type' in 'select type'
# [Substring wins] 'number' in 'number of votes'
# [Substring wins] 'value' in 'avrg value'
# [Substring wins] 'value' in 'max value'
# [Substring wins] 'value' in 'min value'
# [Substring wins] 'number' in 'post number'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'head' in 'head circumference'
# [Substring wins] 'head' in 'head circumference'
# [Substring wins] 'length' in 'sole length'
# [Substring wins] 'length' in 'sole length'
# [Substring wins] 'width' in 'sole width'
# [Substring wins] 'width' in 'sole width'
# [Substring wins] 'length' in 'sole length'
# [Substring wins] 'length' in 'sole length'
# [Substring wins] 'width' in 'sole width'
# [Substring wins] 'width' in 'sole width'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'organization' in 'from organizations'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'event' in 'fuerteventura'
# [Substring wins] 'ship' in 'ships'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'race' in 'race details'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'school' in 'previous school'
# [Substring wins] 'school' in 'name of school'
# [Substring wins] 'opponent' in 'opponentï¿½ï¿½'
# [Substring wins] 'score' in 'scoreï¿½'
# [Substring wins] 'value' in 'prize value'
# [Substring wins] 'type' in 'type of study'
# [Substring wins] 'author' in 'first author'
# [Substring wins] 'time' in 'local time'
# [Substring wins] 'assets' in 'assets*'
# [Substring wins] 'year' in '1 year'
# [Substring wins] 'year' in '3 year'
# [Substring wins] 'year' in '5 year'
# [Substring wins] 'category' in 'etfdb category'
# [Substring wins] 'mission' in 'commission fee'
# [Substring wins] 'end date' in 'dividend date'
# [Substring wins] 'number' in 'number of holdings'
# [Substring wins] 'head' in 'head to head'
# [Substring wins] 'ratio' in 'concentration'
# [Substring wins] 'time' in 'realtime overall'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'score' in 'score diff'
# [Substring wins] 'feature' in 'feature key'
# [Substring wins] 'feature' in 'feature identifier'
# [Substring wins] 'date' in 'date of birth'
# [Substring wins] 'date' in 'date of death'
# [Substring wins] 'country' in 'primary country'
# [Substring wins] 'number' in '2 pt%number'
# [Substring wins] 'number' in '3 pt%number'
# [Substring wins] 'type' in 'remove type'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'code' in 'return code'
# [Substring wins] 'document' in 'document title'
# [Substring wins] 'document' in 'document type'
# [Substring wins] 'number' in 'game number'
# [Substring wins] 'team' in 'home team'
# [Substring wins] 'team' in 'away team'
# [Substring wins] 'title' in 'job title'
# [Substring wins] 'missions' in 'permissions'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'cell name'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'address' in 'mailing address'
# [Substring wins] 'date' in 'issue date'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'other' in 'other occupants'
# [Substring wins] 'director' in 'director info'
# [Substring wins] 'length' in 'length of occupancy'
# [Substring wins] 'price' in 'property price'
# [Substring wins] 'title' in 'side a titles'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'rank' in 'pv rank'
# [Substring wins] 'band' in '1 band'
# [Substring wins] 'area' in 'us call area'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'score' in 'overall score'
# [Substring wins] 'book' in 'bookseller'
# [Substring wins] 'rank' in 'rank*'
# [Substring wins] 'rank' in 'rank*'
# [Substring wins] 'project' in 'project code name'
# [Substring wins] 'location' in 'location for jumper'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'reference' in 'references'
# [Substring wins] 'name' in 'irc nickname'
# [Substring wins] 'language' in 'native language'
# [Substring wins] 'other language' in 'other languages'
# [Substring wins] 'time' in 'timezone'
# [Substring wins] 'software' in 'software help'
# [Substring wins] 'project' in 'focus projects'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'score' in 'calories points calories miles score'
# [Substring wins] 'play' in 'players'
# [Substring wins] 'start' in 'start time'
# [Substring wins] 'author' in 'author name'
# [Substring wins] 'author' in 'type of author'
# [Substring wins] 'work' in 'work?'
# [Substring wins] 'head' in 'headline'
# [Substring wins] 'code' in 'dialing codes'
# [Substring wins] 'mount' in 'amount'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'mount' in 'amount'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'train' in 'train name'
# [Substring wins] 'date' in 'recording date'
# [Substring wins] 'location' in 'recording location'
# [Substring wins] 'title' in 'job title'
# [Substring wins] 'number' in 'warrantnumber'
# [Substring wins] 'number' in 'casenumber'
# [Substring wins] 'score' in 'goals scored against team'
# [Substring wins] 'person' in 'preis pro person'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'name' in 'first name'
# [Substring wins] 'number' in 'record number'
# [Substring wins] 'catch' in 'catch yards'
# [Substring wins] 'catch' in 'catch tds'
# [Substring wins] 'highest' in 'sim dpschar i lv lchar level challenge score ach points pet score total damage done total damage received total healing done total healing received total kills total kills that grant experience or honor damage score at the proving grounds endless tank score at the proving grounds endless healer score at the proving grounds endless rated battlegrounds played rated battlegrounds won battlegrounds played battlegrounds won arenas played arenas won 2 v 2 matches 2 v 2 victories 3 v 3 matches 3 v 3 victories 5 v 5 matches 5 v 5 victories highest 2 man personal rating highest 3 man personal rating highest 5 man personal rating duels won duels lost battleground honorable kills total honorable kills total deaths from opposite faction pet battles won at max level pv p pet battles won at max level pv p pet battles won through find battle quests completed daily quests completed'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'election' in 'elections'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'member' in 'member name'
# [Substring wins] 'information' in 'date of information'
# [Substring wins] 'date' in 'date of birth'
# [Substring wins] 'name' in 'torrent name'
# [Substring wins] 'file' in 'files'
# [Substring wins] 'event' in 'event name'
# [Substring wins] 'number' in 'call number'
# [Substring wins] 'school' in 'school name'
# [Substring wins] 'rating' in 'great schools rating'
# [Substring wins] 'title' in 'journal title'
# [Substring wins] 'title' in 'article title'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'title' in 'disc 1 titles'
# [Substring wins] 'title' in 'disc 1 titles'
# [Substring wins] 'name' in 'username'
# [Substring wins] 'review' in 'reviews'
# [Substring wins] 'date' in 'key date'
# [Substring wins] 'date' in 'pub date'
# [Substring wins] 'publisher' in 'indicia publisher'
# [Substring wins] 'code' in 'barcode'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'race name'
# [Substring wins] 'race' in 'racers'
# [Substring wins] 'library' in 'tag library'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'course' in 'courses'
# [Substring wins] 'name' in 'dance name'
# [Substring wins] 'type' in 'biotype'
# [Substring wins] 'flag' in 'flags'
# [Substring wins] 'position' in 'opposition'
# [Substring wins] 'date' in 'match date'
# [Substring wins] 'score' in 'scorecard'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'source' in 'resource'
# [Substring wins] 'rank' in 'rank ov'
# [Substring wins] 'description' in 'code=description'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'location' in 'location quotient'
# [Substring wins] 'region' in 'regionscode'
# [Substring wins] 'mount' in 'amount'
# [Substring wins] 'catch' in 'catches'
# [Substring wins] 'feature' in 'feature id'
# [Substring wins] 'number' in 'part number'
# [Substring wins] 'height' in 'ant height'
# [Substring wins] 'height' in 'struc height'
# [Substring wins] 'number' in 'loc number'
# [Substring wins] 'mission' in 'emission'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'operator' in 'operators'
# [Substring wins] 'value' in 'values'
# [Substring wins] 'title' in 'job title'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'strength' in 'original strength'
# [Substring wins] 'member' in 'members required'
# [Substring wins] 'time' in 'time of planning'
# [Substring wins] 'school' in 'school name'
# [Substring wins] 'course' in 'course code'
# [Substring wins] 'description' in 'course description'
# [Substring wins] 'member' in 'member rank'
# [Substring wins] 'district' in 'district rank'
# [Substring wins] 'part' in 'part no'
# [Substring wins] 'shuttle' in '20 yard shuttle'
# [Substring wins] 'road' in 'broad jump'
# [Substring wins] 'score' in 'goal scorer'
# [Substring wins] 'description' in 'brief description'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'description' in 'variable description'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'position' in 'opposition'
# [Substring wins] 'score' in 'goal scorer'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'call number'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'rank' in 'rank*'
# [Substring wins] 'selection' in 'player selection'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'student' in 'students'
# [Substring wins] 'rating' in 'great schools rating *'
# [Substring wins] 'leader' in 'team leaders'
# [Substring wins] 'date' in 'dates of trip'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'number of bills'
# [Substring wins] 'member' in 'rank of 102 members'
# [Substring wins] 'media' in 'median'
# [Substring wins] 'name' in 'allele name'
# [Substring wins] 'name' in '| torrent name'
# [Substring wins] 'number' in 'number of instances'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'score' in 'goals scored'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'swimmer' in 'swimmers'
# [Substring wins] 'name' in 'name contact'
# [Substring wins] 'highest' in 'sim dpschar i lv lchar level challenge score ach points pet score total damage done total damage received total healing done total healing received total kills total kills that grant experience or honor damage score at the proving grounds endless tank score at the proving grounds endless healer score at the proving grounds endless rated battlegrounds played rated battlegrounds won battlegrounds played battlegrounds won arenas played arenas won 2 v 2 matches 2 v 2 victories 3 v 3 matches 3 v 3 victories 5 v 5 matches 5 v 5 victories highest 2 man personal rating highest 3 man personal rating highest 5 man personal rating duels won duels lost battleground honorable kills total honorable kills total deaths from opposite faction pet battles won at max level pv p pet battles won at max level pv p pet battles won through find battle quests completed daily quests completed'
# [Substring wins] 'updated' in 'last updated'
# [Substring wins] 'book' in 'book store'
# [Substring wins] 'draft' in 'drafted'
# [Substring wins] 'information' in 'date of information'
# [Substring wins] 'information' in 'date of information'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'single' in 'single icon'
# [Substring wins] 'field' in 'dc field'
# [Substring wins] 'office' in 'post office'
# [Substring wins] 'media' in 'median'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'part number'
# [Substring wins] 'price' in 'list price'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'rank' in 'rank*'
# [Substring wins] 'name' in 'user name'
# [Substring wins] 'member' in 'member since'
# [Substring wins] 'play' in 'favorite past chiefs player'
# [Substring wins] 'play' in 'favorite current chiefs player'
# [Substring wins] 'updated' in 'last updated'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'activity' in 'activity type'
# [Substring wins] 'years' in 'years snubbed'
# [Substring wins] 'number' in 'number of years nominated'
# [Substring wins] 'name' in 'attribute name'
# [Substring wins] 'type' in 'data type'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'author' in 'authors'
# [Substring wins] 'product' in 'commercial products'
# [Substring wins] 'scientific name' in 'scientific name and common name'
# [Substring wins] 'number' in 'gnumber'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'score' in 'score before'
# [Substring wins] 'score' in 'score after'
# [Substring wins] 'number' in 'serial number'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'api name'
# [Substring wins] 'name' in 'entity name'
# [Substring wins] 'date' in 'grant date'
# [Substring wins] 'date' in 'baptism date'
# [Substring wins] 'person' in 'person baptised'
# [Substring wins] 'parent' in 'parents' names'
# [Substring wins] 'name' in 'surname'
# [Substring wins] 'profession' in 'quality, trade or profession'
# [Substring wins] 'office' in 'box office'
# [Substring wins] 'date' in 'seed date'
# [Substring wins] 'other' in 'other seeders'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'title' in 'song title'
# [Substring wins] 'play' in 'played when'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'relative' in 'possible relatives'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'industry' in 'industry rank'
# [Substring wins] 'rank' in 'fastest growing rank'
# [Substring wins] 'revenue' in 'revenues'
# [Substring wins] 'district' in 'present district'
# [Substring wins] 'volume' in 'volume nos'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'film' in 'film no'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'highest' in 'highest level'
# [Substring wins] 'name' in 'file name'
# [Substring wins] 'version' in 'file version'
# [Substring wins] 'service' in 'service branch'
# [Substring wins] 'product' in 'primary vendor product'
# [Substring wins] 'score' in 'cvss score'
# [Substring wins] 'source' in 'source & patch info'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'item name'
# [Substring wins] 'review' in 'review date'
# [Substring wins] 'comment' in 'comment date'
# [Substring wins] 'number' in 'call number'
# [Substring wins] 'status' in 'item status'
# [Substring wins] 'relation' in 'board relationships'
# [Substring wins] 'member' in 'type of board member'
# [Substring wins] 'company' in 'primary company'
# [Substring wins] 'rank' in 'rank*'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'date' in 'observation date'
# [Substring wins] 'date' in 'verified date'
# [Substring wins] 'school' in 'school name'
# [Substring wins] 'rating' in 'great schools rating'
# [Substring wins] 'parent' in 'parent rating'
# [Substring wins] 'distance' in 'distance offshore'
# [Substring wins] 'type' in 'technology type'
# [Substring wins] 'review' in 'preview'
# [Substring wins] 'play' in 'played matches'
# [Substring wins] 'catch' in 'catching'
# [Substring wins] 'field' in 'left field'
# [Substring wins] 'center' in 'center field'
# [Substring wins] 'field' in 'right field'
# [Substring wins] 'games' in 'games batting'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'industry' in 'percent of industry employment'
# [Substring wins] 'project' in 'project name'
# [Substring wins] 'partner' in 'partners'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'transmission' in 'emission & transmission ã— emission'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'start' in 'start time'
# [Substring wins] 'position' in 'company & position'
# [Substring wins] 'date' in 'last date'
# [Substring wins] 'mount' in 'amount'
# [Substring wins] 'course' in 'course name'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'course' in 'course number'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'gnumber'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'score' in 'score before'
# [Substring wins] 'score' in 'score after'
# [Substring wins] 'number' in 'number of wins'
# [Substring wins] 'play' in 'winning player'
# [Substring wins] 'play' in 'losing player'
# [Substring wins] 'name' in 'first name'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'score' in 'accomplish score'
# [Substring wins] 'score' in 'popularity score'
# [Substring wins] 'state' in 'city, state'
# [Substring wins] 'event' in 'most recent event'
# [Substring wins] 'name' in 'session name'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'year' in 'prospect year'
# [Substring wins] 'date' in 'issue date'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'emergency order number'
# [Substring wins] 'information' in 'date of information'
# [Substring wins] 'rank' in 'conf rank'
# [Substring wins] 'league' in 'league range'
# [Substring wins] 'score' in 'percentile score'
# [Substring wins] 'rank' in 'previous rank'
# [Substring wins] 'team point' in 'total team points'
# [Substring wins] 'revenue' in 'data revenues'
# [Substring wins] 'revenue' in 'voice revenues'
# [Substring wins] 'name' in 'tracker name'
# [Substring wins] 'type' in 'program type'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'position' in 'opposition'
# [Substring wins] 'date' in 'match date'
# [Substring wins] 'score' in 'scorecard'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'course' in 'course rating'
# [Substring wins] 'description' in 'company description'
# [Substring wins] 'mountain' in 'mountainchain'
# [Substring wins] 'rating' in 'climbbybike difficulty rating'
# [Substring wins] 'route' in 'route name'
# [Substring wins] 'number' in 'number bolts'
# [Substring wins] 'information' in 'informations sur la couleur'
# [Substring wins] 'number' in 'digi key part number'
# [Substring wins] 'manufacturer' in 'manufacturer part number'
# [Substring wins] 'price' in 'unit price'
# [Substring wins] 'comment' in 'comments'
# [Substring wins] 'event' in 'upcoming events & speeches'
# [Substring wins] 'language' in 'language arts'
# [Substring wins] 'brand' in 'tire brand and model'
# [Substring wins] 'revenue' in 'lfq revenue'
# [Substring wins] 'income' in 'share of household income spent on rent'
# [Substring wins] 'state' in 'city compared to state'
# [Substring wins] 'state' in 'city compared to state'
# [Substring wins] 'title' in 'research title'
# [Substring wins] 'language' in 'language english chinese french german italian russian spanish all'
# [Substring wins] 'type' in 'type manual all'
# [Substring wins] 'date' in 'last update'
# [Substring wins] 'family member' in 'from family members'
# [Substring wins] 'family member' in 'from lobbyist and family members'
# [Substring wins] 'area' in 'metro area'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'rating' in 'my rating'
# [Substring wins] 'number' in 'diagram number'
# [Substring wins] 'number' in 'part number'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'ship' in 'ships'
# [Substring wins] 'name' in 'file name'
# [Substring wins] 'file' in 'filesize'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'name' in 'first name'
# [Substring wins] 'discharge' in 'discharge grade'
# [Substring wins] 'access' in 'accession'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'name' in 'first name'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'title' in 'report title'
# [Substring wins] 'file' in 'file ext'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'swimmer' in 'swimmers'
# [Substring wins] 'name' in 'file name'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'rank' in 'opp rank'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'regime' in 'regimen'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'author' in 'total authorized amount'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'model' in 'make & model'
# [Substring wins] 'rank' in 'employment rank'
# [Substring wins] 'rank' in 'wage rank'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'place' in 'birthplace'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'event' in 'event type'
# [Substring wins] 'name' in 'assignee name'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'franchise name'
# [Substring wins] 'start' in 'startup costs'
# [Substring wins] 'length' in 'foot length'
# [Substring wins] 'time' in 'local time'
# [Substring wins] 'time' in 'my time'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'df e' in 'format pdf this format preserves the paper layout, and is watermarked epub this format allows documents to be read on tablets and smartphones colour pdf enhanced user friendly colour pdf format redline see any updates made from previous versions at a glance paper normally a4 size documents shipping costs apply'
# [Substring wins] 'name' in 'username'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'access' in 'last access'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'position' in 'opposition'
# [Substring wins] 'date' in 'match date'
# [Substring wins] 'number' in 'model number'
# [Substring wins] 'depth' in 'running depth'
# [Substring wins] 'review' in 'reviews'
# [Substring wins] 'date' in 'last date â–²'
# [Substring wins] 'owner' in 'owner type'
# [Substring wins] 'price' in 'last price'
# [Substring wins] 'family' in 'total from lobbyist + family'
# [Substring wins] 'date' in 'pub date'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'horse' in 'horse name'
# [Substring wins] 'mount' in 'amount'
# [Substring wins] 'year' in 'yearly'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'project' in 'project title'
# [Substring wins] 'project' in 'project id'
# [Substring wins] 'mount' in 'commitment amount *'
# [Substring wins] 'date' in 'approval date'
# [Substring wins] 'number' in 'gamenumber'
# [Substring wins] 'block' in 'block?'
# [Substring wins] 'mount' in 'amount?'
# [Substring wins] 'type' in 'type?'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'director' in 'directory'
# [Substring wins] 'document' in 'document type'
# [Substring wins] 'percentage' in 'percentage of applications'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'year' in 'grad year'
# [Substring wins] 'assets' in '% of assets'
# [Substring wins] 'date' in 'as of date'
# [Substring wins] 'type' in 'transaction type'
# [Substring wins] 'document' in 'documentation'
# [Substring wins] 'number' in 'srnumber'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'number' in 'item number'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'rank' in 'rank*'
# [Substring wins] 'rating' in 'users' rating'
# [Substring wins] 'review' in 'review date'
# [Substring wins] 'updated' in 'updated on'
# [Substring wins] 'type' in 'room type'
# [Substring wins] 'price' in 'cabin price'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'score' in 'calories calories miles score'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'shoot' in 'shooting'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'time' in 'reaction time'
# [Substring wins] 'equity' in 'equity swap involved'
# [Substring wins] 'type' in 'form type'
# [Substring wins] 'owner' in 'nature of ownership'
# [Substring wins] 'nation' in 'explanation'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'type' in 'business type'
# [Substring wins] 'committee' in 'committee name'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'course' in 'course number'
# [Substring wins] 'city' in 'rank in city'
# [Substring wins] 'mount' in 'amount'
# [Substring wins] 'interest' in 'est interest rate'
# [Substring wins] 'origin' in 'originator'
# [Substring wins] 'date' in 'baptism date'
# [Substring wins] 'child' in 'child name'
# [Substring wins] 'parent' in 'parent name'
# [Substring wins] 'number' in 'routing number'
# [Substring wins] 'name' in 'attribute name'
# [Substring wins] 'number' in 'approxamite number'
# [Substring wins] 'frequency' in '% frequency'
# [Substring wins] 'period' in 'cancellation period'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'score' in 'score diff'
# [Substring wins] 'product' in 'productnaam'
# [Substring wins] 'date' in 'date & time'
# [Substring wins] 'ratio' in 'operation'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'student' in 'student teacher ratio'
# [Substring wins] 'place' in 'placement'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'team' in 'home team'
# [Substring wins] 'team' in 'away team'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'position' in 'position gain'
# [Substring wins] 'number' in 'numbercar'
# [Substring wins] 'number' in 'numberyr'
# [Substring wins] 'number' in 'numbergm'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'description' in 'play description'
# [Substring wins] 'block' in 'blocking chances'
# [Substring wins] 'block' in 'blocking runs'
# [Substring wins] 'block' in 'blocking runs per 7000'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'order' in 'order code'
# [Substring wins] 'price' in 'net price'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'hand' in 'shipping and handling'
# [Substring wins] 'number' in 'section number'
# [Substring wins] 'river' in 'driver date'
# [Substring wins] 'operating system' in 'operating systems'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'branch name'
# [Substring wins] 'title' in 'card title'
# [Substring wins] 'value' in 'est retail value'
# [Substring wins] 'grades' in 'grades available at nearmintcards com'
# [Substring wins] 'member' in 'members'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'isbn' in 'isbn 13'
# [Substring wins] 'rating' in 'avg rating'
# [Substring wins] 'rating' in 'num ratings'
# [Substring wins] 'date' in 'date pub'
# [Substring wins] 'date' in 'date pub'
# [Substring wins] 'rating' in 'my rating'
# [Substring wins] 'comment' in 'comments'
# [Substring wins] 'start' in 'date started'
# [Substring wins] 'date' in 'date read'
# [Substring wins] 'date' in 'date added'
# [Substring wins] 'date' in 'date purchased'
# [Substring wins] 'location' in 'purchase location'
# [Substring wins] 'date' in 'post date'
# [Substring wins] 'title' in 'job title'
# [Substring wins] 'result' in 'results'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'value' in 'value of shares'
# [Substring wins] 'value' in 'change in value'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'mashup name'
# [Substring wins] 'comment' in 'comments'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'year' in 'all star year'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'date' in 'game date'
# [Substring wins] 'number' in 'c gnumber'
# [Substring wins] 'start' in 'date start'
# [Substring wins] 'time' in 'time slot'
# [Substring wins] 'number' in 'number exp'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'item number'
# [Substring wins] 'type' in 'file type icon'
# [Substring wins] 'name' in 'file name'
# [Substring wins] 'position' in 'role position'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'single' in 'single icon'
# [Substring wins] 'location' in 'location icon'
# [Substring wins] 'assets' in '% assets'
# [Substring wins] 'reference' in 'preference'
# [Substring wins] 'source' in 'resource ã¢â€“â ²'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'mount' in 'amount'
# [Substring wins] 'interest' in 'interest group'
# [Substring wins] 'number' in 'number name'
# [Substring wins] 'year' in 'b year'
# [Substring wins] 'reference' in 'reference*'
# [Substring wins] 'service' in 'service type'
# [Substring wins] 'population' in 'population estimate'
# [Substring wins] 'criteria' in 'iba criteria'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'time' in 'timestamp'
# [Substring wins] 'name' in 'go term name'
# [Substring wins] 'date' in 'date of birth'
# [Substring wins] 'nation' in 'international since'
# [Substring wins] 'limit' in 'use limitation'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'type' in 'feedback type'
# [Substring wins] 'score' in 'avg score'
# [Substring wins] 'number' in 'diagram number'
# [Substring wins] 'number' in 'part number'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'ship' in 'ships'
# [Substring wins] 'rank' in '1970 rank'
# [Substring wins] 'name' in 'song name'
# [Substring wins] 'position' in 'peak position'
# [Substring wins] 'name' in 'crag name'
# [Substring wins] 'number' in 'warning number'
# [Substring wins] 'location' in 'allocation'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'number' in 'mlsnumber'
# [Substring wins] 'date' in 'last update type'
# [Substring wins] 'name' in 'broker name'
# [Substring wins] 'gender' in 'gender age div'
# [Substring wins] 'coach' in 'asst coach'
# [Substring wins] 'event' in 'event name'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'docket number'
# [Substring wins] 'name' in 'first name'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'code' in 'asx code'
# [Substring wins] 'head' in 'headline'
# [Substring wins] 'title' in 'side b titles'
# [Substring wins] 'school' in 'other nearby schools'
# [Substring wins] 'rating' in 'great schools rating'
# [Substring wins] 'parent' in 'parent rating'
# [Substring wins] 'average' in 'average price'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'first name'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'course' in 'course name'
# [Substring wins] 'type' in 'hole type'
# [Substring wins] 'type' in 'tee type'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'place' in 'placement'
# [Substring wins] 'rank' in '500 rank'
# [Substring wins] 'revenue' in 'revenues'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'file' in 'files'
# [Substring wins] 'height' in 'base height'
# [Substring wins] 'height' in 'height modifier'
# [Substring wins] 'weight' in 'base weight'
# [Substring wins] 'weight' in 'weight modifier'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'publisher' in 'publisher â»'
# [Substring wins] 'play' in 'players'
# [Substring wins] 'date' in 'eu date'
# [Substring wins] 'date' in 'date submitted'
# [Substring wins] 'date' in 'date corrected'
# [Substring wins] 'type' in 'body type'
# [Substring wins] 'movement' in 'schools & movements'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'api name'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'event' in 'past events attended'
# [Substring wins] 'date' in 'date of naming'
# [Substring wins] 'architect' in 'architecture'
# [Substring wins] 'model' in 'model no'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'vehicle' in 'important vehicle option details'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'document' in 'document type'
# [Substring wins] 'number' in 'partnumber'
# [Substring wins] 'origin' in 'titolo originale'
# [Substring wins] 'field' in 'example field'
# [Substring wins] 'output' in 'using joda time output'
# [Substring wins] 'style' in 'style used'
# [Substring wins] 'language' in 'languages'
# [Substring wins] 'comment' in 'comments'
# [Substring wins] 'interest' in '$ from interest groups that supported'
# [Substring wins] 'interest' in '$ from interest groups that opposed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'title' in 'news title'
# [Substring wins] 'category' in 'news category'
# [Substring wins] 'work' in 'workers'
# [Substring wins] 'other' in 'pct other'
# [Substring wins] 'type' in 'you type'
# [Substring wins] 'document' in 'document title'
# [Substring wins] 'date' in 'cover date'
# [Substring wins] 'institution' in 'higher education institution'
# [Substring wins] 'type' in 'degree type'
# [Substring wins] 'time' in 'time left'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'election' in 'election day'
# [Substring wins] 'board' in 'mainboard'
# [Substring wins] 'bridge' in 'northbridge'
# [Substring wins] 'bridge' in 'southbridge'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'average' in 'average price'
# [Substring wins] 'type' in 'subtype'
# [Substring wins] 'office' in 'office phone'
# [Substring wins] 'location' in 'office location'
# [Substring wins] 'source' in 'primary source'
# [Substring wins] 'date' in 'date available'
# [Substring wins] 'project' in 'projects'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'year' in 'year independence gained'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'catch' in 'catches'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'catch' in 'catches'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'rating' in 'rivals rating'
# [Substring wins] 'rank' in 'pos rank'
# [Substring wins] 'rank' in 'nat rank'
# [Substring wins] 'state' in 'state rank'
# [Substring wins] 'date' in 'visit date'
# [Substring wins] 'name' in 'file name'
# [Substring wins] 'version' in 'file version'
# [Substring wins] 'name' in 'ride name'
# [Substring wins] 'length' in 'ride length'
# [Substring wins] 'address' in 'ip address'
# [Substring wins] 'number' in 'as number'
# [Substring wins] 'title' in 'job title'
# [Substring wins] 'name' in 'tournament'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'project' in 'project name'
# [Substring wins] 'type' in 'types of assistance'
# [Substring wins] 'number' in 'approval number'
# [Substring wins] 'date' in 'approval date'
# [Substring wins] 'source' in 'resource â–²'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'class number'
# [Substring wins] 'course' in 'course title'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'date' in 'dates de vol'
# [Substring wins] 'march' in 'marchand'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'length' in 'length of stay'
# [Substring wins] 'program cost' in 'dpt basic program costs'
# [Substring wins] 'source' in 'resource type'
# [Substring wins] 'comment' in 'customer comment'
# [Substring wins] 'number' in 'photos any number 1 or more 5 or more 10 or more 15 or more 20 or more 25 or more 0 no photo'
# [Substring wins] 'price' in 'show price'
# [Substring wins] 'status' in 'status active any active'
# [Substring wins] 'family' in 'snapshot single family condo'
# [Substring wins] 'play' in 'display nearby'
# [Substring wins] 'source' in 'mls source metrolist mls idxmetrolist & ires idx'
# [Substring wins] 'product' in 'product type'
# [Substring wins] 'date' in 'update'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'part' in 'departure'
# [Substring wins] 'river' in 'driver name'
# [Substring wins] 'hand' in 'postage and handling'
# [Substring wins] 'name' in 'tournaments played'
# [Substring wins] 'average' in 'stroke average'
# [Substring wins] 'position' in 'average position'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'score' in 'miles points calories miles score'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'score' in 'points calories miles score'
# [Substring wins] 'access' in 'accession number'
# [Substring wins] 'name' in 'file name'
# [Substring wins] 'number' in 'collector and number'
# [Substring wins] 'name' in 'first name'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'price' in 'trade price'
# [Substring wins] 'type' in 'mast type'
# [Substring wins] 'length' in 'mast length'
# [Substring wins] 'country' in 'rank within country'
# [Substring wins] 'number' in 'srnumber'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'name' in 'soldier name'
# [Substring wins] 'number' in 'pension number'
# [Substring wins] 'location' in 'location code'
# [Substring wins] 'channel' in 'channel code'
# [Substring wins] 'flag' in 'flags'
# [Substring wins] 'result' in 'result date'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'member' in 'members'
# [Substring wins] 'world' in 'world rank'
# [Substring wins] 'ratio' in 'loss ratio'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'school' in 'miles from home school'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'name' in 'first name'
# [Substring wins] 'priest' in 'diocesan priests'
# [Substring wins] 'priest' in 'religious priests'
# [Substring wins] 'priest' in 'total priests'
# [Substring wins] 'priest' in 'catholics per priest'
# [Substring wins] 'parish' in 'parishes'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'review' in 'abreviews'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'instrument' in 'cms instruments'
# [Substring wins] 'score' in 'scored by'
# [Substring wins] 'number' in 'number of images'
# [Substring wins] 'name' in 'official trade name'
# [Substring wins] 'type' in 'datatype'
# [Substring wins] 'mount' in 'amount'
# [Substring wins] 'date' in 'ex date'
# [Substring wins] 'date' in 'pay date'
# [Substring wins] 'service' in 'services'
# [Substring wins] 'restriction' in 'restrictions'
# [Substring wins] 'date' in 'candidate'
# [Substring wins] 'mount' in 'amount'
# [Substring wins] 'updated' in 'last updated'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'address' in 'email address'
# [Substring wins] 'team' in 'home team'
# [Substring wins] 'team' in 'away team'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'source' in 'source package'
# [Substring wins] 'command' in 'command line switch'
# [Substring wins] 'command' in 'command line argument'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'height' in 'width and height'
# [Substring wins] 'area' in 'protected area'
# [Substring wins] 'nation' in 'designation'
# [Substring wins] 'relation' in 'relationship with iba'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'item number'
# [Substring wins] 'date' in 'date and time'
# [Substring wins] 'team' in 'teams playing'
# [Substring wins] 'promotion' in 'promotions'
# [Substring wins] 'start' in 'starts'
# [Substring wins] 'second' in 'seconds'
# [Substring wins] 'third' in 'thirds'
# [Substring wins] 'code' in 'sale code'
# [Substring wins] 'sire' in 'cover sire'
# [Substring wins] 'member' in 'members'
# [Substring wins] 'games' in 'games batting'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'play' in 'players'
# [Substring wins] 'score' in 'goals scored'
# [Substring wins] 'version' in 'versions'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'box name'
# [Substring wins] 'city' in 'nearby city'
# [Substring wins] 'access' in 'mgi source accession'
# [Substring wins] 'gene' in 'top affiliating genes'
# [Substring wins] 'name' in 'user name'
# [Substring wins] 'name' in 'real name'
# [Substring wins] 'start' in 'starts'
# [Substring wins] 'number' in 'part number'
# [Substring wins] 'number' in 'number of bills'
# [Substring wins] 'member' in 'rank of 448 members'
# [Substring wins] 'media' in 'median'
# [Substring wins] 'model' in 'sub model'
# [Substring wins] 'state' in 'percent of state employment'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'result' in 'results'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'county' in 'county [download csv]'
# [Substring wins] 'order' in 'call order'
# [Substring wins] 'project' in 'project number'
# [Substring wins] 'number' in 'control number'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'type' in 'release type'
# [Substring wins] 'version' in 'game version'
# [Substring wins] 'author' in 'authors'
# [Substring wins] 'author' in 'author shares'
# [Substring wins] 'type' in 'holiday type'
# [Substring wins] 'average' in 'average price'
# [Substring wins] 'date' in 'date filed'
# [Substring wins] 'number' in 'file number'
# [Substring wins] 'status' in 'status date'
# [Substring wins] 'period' in 'distribution period'
# [Substring wins] 'head' in 'column heading'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'product' in 'product name'
# [Substring wins] 'number' in 'number stocked'
# [Substring wins] 'number' in 'no number'
# [Substring wins] 'number' in 'no number'
# [Substring wins] 'title' in 'side d titles'
# [Substring wins] 'season' in 'season pts'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'part number'
# [Substring wins] 'model' in 'model application'
# [Substring wins] 'route' in 'route name'
# [Substring wins] 'number' in 'number of bolts'
# [Substring wins] 'number' in 'photos any number 1 or more 5 or more 10 or more 15 or more 20 or more 25 or more 0 no photo'
# [Substring wins] 'price' in 'show price'
# [Substring wins] 'status' in 'status active any active'
# [Substring wins] 'family' in 'snapshot single family condo'
# [Substring wins] 'play' in 'display nearby'
# [Substring wins] 'source' in 'mls source metrolist & ires idxmetrolist mls idxires idx'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'score' in 'miles calories miles score'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'lastname'
# [Substring wins] 'name' in 'shirt name'
# [Substring wins] 'date' in 'birthdate'
# [Substring wins] 'relation' in 'media relations'
# [Substring wins] 'address' in 'name and address'
# [Substring wins] 'number' in 'telephone number'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'item number'
# [Substring wins] 'mount' in 'amount'
# [Substring wins] 'position' in 'peak position'
# [Substring wins] 'league' in '4a 3 far west league'
# [Substring wins] 'date' in 'dates served'
# [Substring wins] 'name' in 'tag name'
# [Substring wins] 'position' in 'position â†‘'
# [Substring wins] 'rank' in 'ranks'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'rank number'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'place' in 'place %'
# [Substring wins] 'highest' in 'sim dpschar i lv lchar level challenge score ach points pet score total damage done total damage received total healing done total healing received total kills total kills that grant experience or honor damage score at the proving grounds endless tank score at the proving grounds endless healer score at the proving grounds endless rated battlegrounds played rated battlegrounds won battlegrounds played battlegrounds won arenas played arenas won 2 v 2 matches 2 v 2 victories 3 v 3 matches 3 v 3 victories 5 v 5 matches 5 v 5 victories highest 2 man personal rating highest 3 man personal rating highest 5 man personal rating duels won duels lost battleground honorable kills total honorable kills total deaths from opposite faction pet battles won at max level pv p pet battles won at max level pv p pet battles won through find battle quests completed daily quests completed'
# [Substring wins] 'language' in 'language key'
# [Substring wins] 'country' in 'country â–²'
# [Substring wins] 'scale' in 'progress scale'
# [Substring wins] 'language' in 'primary language'
# [Substring wins] 'religion' in 'primary religion'
# [Substring wins] 'number' in 'number produit'
# [Substring wins] 'comment' in 'comments'
# [Substring wins] 'date' in 'tick date'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'model number'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'start' in 'start stop times'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'relation' in 'board relationships'
# [Substring wins] 'relation' in 'board relationships'
# ...
# [Substring wins] 'amount' in 'amount awarded'
# [Substring wins] 'place' in 'placement at miss teen usa'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'play' in 'players'
# [Substring wins] 'date' in 'eu date'
# [Substring wins] 'result' in 'result date'
# [Substring wins] 'time' in 'lifetime'
# [Substring wins] 'date' in 'accident date'
# [Substring wins] 'patient' in 'number of patients'
# [Substring wins] 'size' in 'jacadi size'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'user name'
# [Substring wins] 'date' in 'join date'
# [Substring wins] 'genre' in 'preferred genres'
# [Substring wins] 'game' in 'games behind'
# [Substring wins] 'number' in 'item number'
# [Substring wins] 'number' in 'container number'
# [Substring wins] 'area' in 'container area'
# [Substring wins] 'position' in 'disposition'
# [Substring wins] 'number' in 'number of unsplit'
# [Substring wins] 'number' in 'item number'
# [Substring wins] 'number' in 'container number'
# [Substring wins] 'area' in 'container area'
# [Substring wins] 'comment' in 'clint comment'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'lastname'
# [Substring wins] 'name' in 'shirt name'
# [Substring wins] 'date' in 'birthdate'
# [Substring wins] 'parent' in 'parent division'
# [Substring wins] 'name' in 'name variants'
# [Substring wins] 'area' in 'metropolitan area'
# [Substring wins] 'area' in 'area code'
# [Substring wins] 'code' in 'zip code'
# [Substring wins] 'time' in 'time zone'
# [Substring wins] 'number' in 'model number'
# [Substring wins] 'depth' in 'running depth'
# [Substring wins] 'number' in 'number of cases'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'company name'
# [Substring wins] 'track' in 'track type'
# [Substring wins] 'name' in 'name and type'
# [Substring wins] 'opponent' in 'remaining opponents'
# [Substring wins] 'actor' in 'reactor type'
# [Substring wins] 'city' in 'capacity'
# [Substring wins] 'date' in 'date of commercial operation'
# [Substring wins] 'area' in 'all dv chargeability areas except those listed separately'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'friday' in 'friday 9'
# [Substring wins] 'saturday' in 'saturday 9'
# [Substring wins] 'sunday' in 'sunday 9'
# [Substring wins] 'friday' in 'friday 11'
# [Substring wins] 'saturday' in 'saturday 11'
# [Substring wins] 'sunday' in 'sunday 11'
# [Substring wins] 'country' in 'country code'
# [Substring wins] 'category' in 'contact category'
# [Substring wins] 'category' in 'caller category'
# [Substring wins] 'product' in 'product or service'
# [Substring wins] 'language' in 'service language'
# [Substring wins] 'date' in 'date range'
# [Substring wins] 'schedule' in 'schedule type'
# [Substring wins] 'instructor' in 'instructors'
# [Substring wins] 'play' in 'plays'
# [Substring wins] 'name' in 'nonprofit name'
# [Substring wins] 'amount' in 'grant amount'
# [Substring wins] 'text' in 'text being analysed'
# [Substring wins] 'thing' in 'thingy'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'language' in 'delivery language'
# [Substring wins] 'material' in 'material collected'
# [Substring wins] 'name' in 'story name'
# [Substring wins] 'class' in 'classification value'
# [Substring wins] 'product' in 'sonoco products co'
# [Substring wins] 'name' in 'university name'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'time' in 'overtime expenditure'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'pond' in 'corresponding dmd flag'
# [Substring wins] 'option' in 'build options'
# [Substring wins] 'number' in 'item number'
# [Substring wins] 'city' in 'home of record city'
# [Substring wins] 'date' in 'date of birth'
# [Substring wins] 'date' in 'date of death'
# [Substring wins] 'place' in 'place of death'
# [Substring wins] 'parents' in 'godparents'
# [Substring wins] 'name' in 'tournament'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'license' in 'licensed captain'
# [Substring wins] 'license' in 'licensed captain'
# [Substring wins] 'price' in 'our price'
# [Substring wins] 'number' in 'part number'
# [Substring wins] 'color' in 'fabric color'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'stock number'
# [Substring wins] 'friday' in 'friday 11'
# [Substring wins] 'saturday' in 'saturday 11'
# [Substring wins] 'sunday' in 'sunday 11'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'employee' in 'passenger per employee'
# [Substring wins] 'name' in 'team name'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'brand' in 'brands'
# [Substring wins] 'date' in 'dateadded'
# [Substring wins] 'address' in 'ip address'
# [Substring wins] 'online' in 'files online'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'value' in 'cap value'
# [Substring wins] 'friday' in 'friday 3'
# [Substring wins] 'saturday' in 'saturday 3'
# [Substring wins] 'sunday' in 'sunday 3'
# [Substring wins] 'date' in 'date of birth'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'web site' in 'name and web site link'
# [Substring wins] 'service' in 'services'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'game' in 'per game'
# [Substring wins] 'date' in 'publishing date'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'comment' in 'notes & comments'
# [Substring wins] 'seat' in 'seat size'
# [Substring wins] 'name' in 'surname'
# [Substring wins] 'name' in 'first name'
# [Substring wins] 'state' in 'city & state'
# [Substring wins] 'date' in 'show date'
# [Substring wins] 'date' in 'closing date'
# Last run on: 2025-07-08 15:56:23
#                 CleanedColumn Description  \
# 0                          id         NaN
# 1                     country         NaN
# 2                     unnamed           2
# 3            complete o meter         NaN
# 4                     courses         NaN
# 5                         NaN           %
# 6                          id         NaN
# 7                        name        Link
# 8             expertise areas         NaN
# 9                contact info         NaN
# 10               expires date         NaN
# 11                         id         NaN
# 12                       name         NaN
# 13              transcript id         NaN
# 14                         bp         NaN
# 15                    protein         NaN
# 16             translation id         NaN
# 17                    biotype         NaN
# 18                       ccds         NaN
# 19                   uni prot         NaN
# 20                    ref seq         NaN
# 21                      flags         NaN
# 22                         id         NaN
# 23                       code         NaN
# 24                       iata         NaN
# 25                       kind         NaN
# 26                       name         NaN
# 27                       city         NaN
# 28                   distance         NaN
# 29                    bearing         NaN
# 30                   airlines         NaN
# 31                         id         NaN
# 32  patent application number         NaN
# 33                description         NaN
# 34                  published         NaN
# 35                         id         NaN
# 36                       rank         NaN
# 37                       name         NaN
# 38                     medals         NaN
# 39                         id         NaN
# 40                        pos         NaN
# 41                       team         NaN
# 42                          p         NaN
# 43                         gd         NaN
# 44                        pts         NaN
# 45                         id         NaN
# 46                        pos         NaN
# 47                       team         NaN
# 48                        pts         NaN
# 49                         id         NaN
# 50                   question         NaN
# 51                     status         NaN
# 52                       from         NaN
# 53                         id         NaN
# 54                       site         NaN
# 55                       date         NaN
# 56                       type         NaN
# 57                     rating         NaN
# 58                         id         NaN
# 59                       date         NaN
#
#                                            DBpediaType  DBpediaScore  \
# 0                       http://dbpedia.org/ontology/id      1.000000
# 1                  http://dbpedia.org/ontology/Country      1.000000
# 2                     http://dbpedia.org/ontology/name      1.000000
# 3                                                  Nil      0.000000
# 4                   http://dbpedia.org/ontology/course      1.000000
# 5                                                  Nil      0.000000
# 6                       http://dbpedia.org/ontology/id      1.000000
# 7                     http://dbpedia.org/ontology/name      1.000000
# 8                     http://dbpedia.org/ontology/area      1.000000
# 9                                                  Nil      0.000000
# 10                    http://dbpedia.org/ontology/date      1.000000
# 11                      http://dbpedia.org/ontology/id      1.000000
# 12                    http://dbpedia.org/ontology/name      1.000000
# 13                      http://dbpedia.org/ontology/id      0.990921
# 14              http://dbpedia.org/ontology/bloodGroup      0.811055
# 15                 http://dbpedia.org/ontology/Protein      1.000000
# 16                      http://dbpedia.org/ontology/id      0.995542
# 17                    http://dbpedia.org/ontology/type      1.000000
# 18                                                 Nil      0.000000
# 19                                                 Nil      0.000000
# 20                                                 Nil      0.000000
# 21                    http://dbpedia.org/ontology/Flag      1.000000
# 22                      http://dbpedia.org/ontology/id      1.000000
# 23                    http://dbpedia.org/ontology/code      1.000000
# 24  http://dbpedia.org/ontology/iataLocationIdentifier      0.898522
# 25                                                 Nil      0.000000
# 26                    http://dbpedia.org/ontology/name      1.000000
# 27                    http://dbpedia.org/ontology/City      1.000000
# 28                http://dbpedia.org/ontology/distance      1.000000
# 29                                                 Nil      0.000000
# 30                 http://dbpedia.org/ontology/Airline      1.000000
# 31                      http://dbpedia.org/ontology/id      1.000000
# 32                  http://dbpedia.org/ontology/number      1.000000
# 33             http://dbpedia.org/ontology/description      1.000000
# 34                                                 Nil      0.000000
# 35                      http://dbpedia.org/ontology/id      1.000000
# 36                    http://dbpedia.org/ontology/rank      1.000000
# 37                    http://dbpedia.org/ontology/name      1.000000
# 38                                                 Nil      0.000000
# 39                      http://dbpedia.org/ontology/id      1.000000
# 40                http://dbpedia.org/ontology/position      1.000000
# 41                    http://dbpedia.org/ontology/team      1.000000
# 42                                                 Nil      0.000000
# 43                                                 Nil      0.000000
# 44                                                 Nil      0.000000
# 45                      http://dbpedia.org/ontology/id      1.000000
# 46                http://dbpedia.org/ontology/position      1.000000
# 47                    http://dbpedia.org/ontology/team      1.000000
# 48                                                 Nil      0.000000
# 49                      http://dbpedia.org/ontology/id      1.000000
# 50                                                 Nil      0.000000
# 51                  http://dbpedia.org/ontology/status      1.000000
# 52           http://dbpedia.org/ontology/announcedFrom      0.891915
# 53                      http://dbpedia.org/ontology/id      1.000000
# 54           http://dbpedia.org/ontology/touristicSite      0.881370
# 55                    http://dbpedia.org/ontology/date      1.000000
# 56                    http://dbpedia.org/ontology/type      1.000000
# 57                  http://dbpedia.org/ontology/rating      1.000000
# 58                      http://dbpedia.org/ontology/id      1.000000
# 59                    http://dbpedia.org/ontology/date      1.000000
#
#                          SchemaOrgType  SchemaScore
# 0        https://schema.org/identifier     1.000000
# 1           https://schema.org/Country     1.000000
# 2              https://schema.org/name     1.000000
# 3                                  Nil     0.000000
# 4            https://schema.org/course     1.000000
# 5                                  Nil     0.000000
# 6        https://schema.org/identifier     1.000000
# 7              https://schema.org/name     1.000000
# 8              https://schema.org/area     1.000000
# 9   https://schema.org/prescribingInfo     0.894078
# 10          https://schema.org/expires     1.000000
# 11       https://schema.org/identifier     1.000000
# 12             https://schema.org/name     1.000000
# 13       https://schema.org/transcript     1.000000
# 14      https://schema.org/bloodSupply     0.860483
# 15   https://schema.org/proteinContent     0.868131
# 16       https://schema.org/identifier     0.995542
# 17                                 Nil     0.000000
# 18                                 Nil     0.000000
# 19                                 Nil     0.000000
# 20                                 Nil     0.000000
# 21                                 Nil     0.000000
# 22       https://schema.org/identifier     1.000000
# 23             https://schema.org/Code     1.000000
# 24         https://schema.org/iataCode     0.825913
# 25                                 Nil     0.000000
# 26             https://schema.org/name     1.000000
# 27             https://schema.org/City     1.000000
# 28         https://schema.org/distance     1.000000
# 29                                 Nil     0.000000
# 30          https://schema.org/Airline     1.000000
# 31       https://schema.org/identifier     1.000000
# 32      https://schema.org/application     1.000000
# 33      https://schema.org/description     1.000000
# 34                                 Nil     0.000000
# 35       https://schema.org/identifier     1.000000
# 36                                 Nil     0.000000
# 37             https://schema.org/name     1.000000
# 38                                 Nil     0.000000
# 39       https://schema.org/identifier     1.000000
# 40           https://schema.org/hasPOS     0.854527
# 41       https://schema.org/SportsTeam     0.872975
# 42                                 Nil     0.000000
# 43                                 Nil     0.000000
# 44    https://schema.org/contactPoints     0.780827
# 45       https://schema.org/identifier     1.000000
# 46           https://schema.org/hasPOS     0.854527
# 47       https://schema.org/SportsTeam     0.872975
# 48    https://schema.org/contactPoints     0.780827
# 49       https://schema.org/identifier     1.000000
# 50         https://schema.org/Question     1.000000
# 51           https://schema.org/status     1.000000
# 52   https://schema.org/originatesFrom     0.947953
# 53       https://schema.org/identifier     1.000000
# 54          https://schema.org/WebSite     0.871791
# 55             https://schema.org/Date     1.000000
# 56  https://schema.org/interactionType     0.950787
# 57           https://schema.org/Rating     1.000000
# 58       https://schema.org/identifier     1.000000
# 59             https://schema.org/Date     1.000000

# %%
header = "au release date"
matches = [label for label in dbpedia_labels if (label in header or header in label) and len(label) >= 4]
matches = sorted(matches, key=lambda x: (len(x.split()), len(x)), reverse=True)
print(matches)
# Out:
# ['release date', 'date']

# %% [markdown]
# FinalFormat

# %%
def analysis_of_column(ColumnFormat, DescriptionFormat, DescriptionKeyword, index_value):
    if ColumnFormat is None and DescriptionFormat is None:
        return 'NaN'

    # If either is 'None', choose the one that has a value
    if pd.isnull(ColumnFormat):
        return DescriptionFormat
    elif pd.isnull(DescriptionFormat):
        return ColumnFormat
  
    # Prioritize 'categorical' over 'numerical', but prefer specific numeric types in DescriptionKeyword
    if ColumnFormat == 'categorical' and DescriptionFormat == 'numerical':
        if DescriptionKeyword in ['float', 'double']:
            return DescriptionFormat
        return ColumnFormat
    
    # If one is 'string' and the other is not, choose the one that is not 'string'
    if ColumnFormat == 'string' and DescriptionFormat not in [None, 'string', 'NaN']:
        return DescriptionFormat
    elif DescriptionFormat == 'string' and ColumnFormat not in [None, 'string', 'NaN']:
        return ColumnFormat

    # If one is 'hour' and the other is numerical, choose numerical'
    if ColumnFormat == 'hour' and DescriptionFormat.startswith("numerical"):
        return DescriptionFormat
    elif DescriptionFormat == 'hour' and ColumnFormat.startswith("numerical"):
        return ColumnFormat
    
    # Datetime should always win
    if ColumnFormat == 'datetime' or DescriptionFormat == 'datetime':
        return 'datetime'

    # ID column should always win
    if ColumnFormat == "IDcolumn" or DescriptionFormat == "IDcolumn":
        return "IDcolumn"
    
    # percentage should always win
    if ColumnFormat == "percentage" or DescriptionFormat == "percentage":
        return "percentage"
    
    # binary should always win
    if ColumnFormat == 'binary' or DescriptionFormat == 'binary':
        return 'binary' 

    # If both are 'numerical' or if ColumnFormat is in the predefined list, return ColumnFormat
    if (ColumnFormat.startswith("numerical") and DescriptionFormat.startswith("numerical")) or \
       ColumnFormat in ["phone", "month", "date", "weekday", "week", "year",
                        "country", "state", "city", "street", "name",
                        "latitude", "longitude", "postalcode", "URLformat","IPformat", 
                        "E-mailformat", "binary"]:
        return ColumnFormat
    elif ColumnFormat in ["age"] and DescriptionFormat not in ['categorical']:
        return ColumnFormat
    # If no exceptions apply, return the value from "DescriptionFormat"
    else:
        return DescriptionFormat

# Apply the function to create the new column
analysed_columns_df['FinalFormat'] = analysed_columns_df.apply(
    lambda row: analysis_of_column(
        row['ColumnFormat'],
        row['DescriptionFormat'],
        row['DescriptionKeyword'],
        row['dataset_index']),  
    axis=1
)
print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Last run on: 2025-07-08 15:56:24

# %% [markdown]
# Identify Origin

# %%
def identify_origin(row):
    analysis_col = row['FinalFormat']
    ColumnFormat = row['ColumnFormat']
    DescriptionFormat = row['DescriptionFormat']

    # Check if the value in 'FinalFormat' came from 'ColumnFormat'
    if pd.notnull(ColumnFormat) and analysis_col == ColumnFormat:
        return row['ColumnKeyword']

    # Check if the value in 'FinalFormat' came from 'DescriptionFormat'
    elif pd.notnull(DescriptionFormat) and analysis_col == DescriptionFormat:
        return row['DescriptionKeyword']

    # If none of the above conditions are met, return NaN or any default value you prefer
    else:
        return 'NaN'

# Create the new column 'SourceKeyword' in analysed_columns_df
analysed_columns_df['SourceKeyword'] = analysed_columns_df.apply(identify_origin, axis=1)
print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Last run on: 2025-07-08 15:56:25

# %% [markdown]
# Save results

# %%
# Save the results to a new Excel file
analysed_columns_df.to_excel(analysed_columns_file_path, index=False)

from datetime import datetime
print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Last run on: 2025-07-08 15:56:56
