# %%
import pymysql
import pandas as pd

# Dictionary to map database names to their domains
domain_mapping = {
    "stats": "Education", "UW_std": "Education", "imdb_full": "Entertainment",
    "imdb_MovieLens": "Entertainment", "ccs": "Finance", "financial": "Finance",
    "Countries": "Geography", "Mondial": "Geography", "legalActs": "Government",
    "Mesh": "Industry", "trains": "Logistic", "Biodegradability": "Medicine",
    "Carcinogenesis": "Medicine", "Hepatitis_std": "Medicine", "PTE": "Medicine",
    "classicmodels": "Retail", "Credit": "Retail", "ftp": "Retail",
    "northwind": "Retail", "sakila": "Retail", "SalesDB": "Retail",
    "tpcds": "Retail", "AustralianFootball": "Sport", "Hockey": "Sport",
    "lahman_2014": "Sport"
}

def get_table_info(host, port, user, password, db_name, table_name):
    connection = pymysql.connect(host=host, port=port, user=user, password=password, database=db_name)
    
    try:
        with connection.cursor() as cursor:
            # Get column information
            cursor.execute(f"DESCRIBE `{table_name}`")
            columns = cursor.fetchall()
            
            # Get row count
            cursor.execute(f"SELECT COUNT(*) FROM `{table_name}`")
            row_count = cursor.fetchone()[0]
            
            # Get primary key(s)
            cursor.execute(f"""
                SELECT GROUP_CONCAT(COLUMN_NAME)
                FROM INFORMATION_SCHEMA.KEY_COLUMN_USAGE
                WHERE TABLE_SCHEMA = '{db_name}'
                AND TABLE_NAME = '{table_name}'
                AND CONSTRAINT_NAME = 'PRIMARY'
                GROUP BY TABLE_NAME
            """)
            primary_keys = cursor.fetchone()
            
            # Get foreign keys
            cursor.execute(f"""
                SELECT COLUMN_NAME, REFERENCED_TABLE_NAME, REFERENCED_COLUMN_NAME
                FROM INFORMATION_SCHEMA.KEY_COLUMN_USAGE
                WHERE TABLE_SCHEMA = '{db_name}'
                AND TABLE_NAME = '{table_name}'
                AND REFERENCED_TABLE_NAME IS NOT NULL
            """)
            foreign_keys = cursor.fetchall()
            
            table_info = {
                'index': f"{db_name}.{table_name}",
                'name': table_name,
                'database': db_name,
                'area': domain_mapping.get(db_name, "Unknown"),  # Add this line
                'instances': row_count,
                'attributes': len(columns),
                'Column': ", ".join([col[0] for col in columns]),
                'Description': ", ".join([f"{col[0]} ({col[1]})" for col in columns]),
                'primary_key': primary_keys[0] if primary_keys else None,
                'foreign_keys': ", ".join([f"{fk[0]} -> {fk[1]}.{fk[2]}" for fk in foreign_keys]) if foreign_keys else None
            }
            
            return table_info
    
    finally:
        connection.close()

# Connection details
host = 'db.relational-data.org'
port = 3306
user = 'guest'
password = 'relational'

# List of databases we're interested in
databases = [
    "stats", "UW_std", "imdb_full", "imdb_MovieLens", "ccs", "financial", "Countries",
    "Mondial", "legalActs", "Mesh", "trains", "Biodegradability", "Carcinogenesis",
    "Hepatitis_std", "PTE", "classicmodels", "Credit", "ftp", "northwind", "sakila",
    "SalesDB", "tpcds", "AustralianFootball", "Hockey", "lahman_2014"
]

# Collect information for all tables in the selected databases
all_table_info = []
for db_name in databases:
    try:
        connection = pymysql.connect(host=host, port=port, user=user, password=password, database=db_name)
        with connection.cursor() as cursor:
            cursor.execute("SHOW TABLES")
            tables = [table[0] for table in cursor.fetchall()]
        
        for table_name in tables:
            try:
                table_info = get_table_info(host, port, user, password, db_name, table_name)
                all_table_info.append(table_info)
                print(f"Processed: {db_name}.{table_name}")
            except Exception as e:
                print(f"Error processing {db_name}.{table_name}: {str(e)}")
    except Exception as e:
        print(f"Error connecting to database {db_name}: {str(e)}")
    finally:
        if connection:
            connection.close()

# Create a DataFrame with the collected information
df = pd.DataFrame(all_table_info)

# Save to Excel
df.to_excel("all_selected_databases_info.xlsx", index=False)

print("Table information for all tables in selected databases has been saved to all_selected_databases_info.xlsx")
print(f"Total tables processed: {len(df)}")
print("\nUnique values in the 'area' column:")
print(df['area'].unique())
# Out:
# Processed: stats.badges
# Processed: stats.comments
# Processed: stats.postHistory
# Processed: stats.postLinks
# Processed: stats.posts
# Processed: stats.tags
# Processed: stats.users
# Processed: stats.votes
# Processed: UW_std.advisedBy
# Processed: UW_std.course
# Processed: UW_std.person
# Processed: UW_std.taughtBy
# Processed: imdb_full.actors
# Processed: imdb_full.business
# Processed: imdb_full.countries
# Processed: imdb_full.directors
# Processed: imdb_full.distributors
# Processed: imdb_full.editors
# Processed: imdb_full.genres
# Processed: imdb_full.language
# Processed: imdb_full.movies
# Processed: imdb_full.movies2actors
# Processed: imdb_full.movies2directors
# Processed: imdb_full.movies2editors
# Processed: imdb_full.movies2producers
# Processed: imdb_full.movies2writers
# Processed: imdb_full.prodcompanies
# Processed: imdb_full.producers
# Processed: imdb_full.ratings
# Processed: imdb_full.runningtimes
# Processed: imdb_full.writers
# Processed: imdb_MovieLens.actors
# Processed: imdb_MovieLens.directors
# Processed: imdb_MovieLens.movies
# Processed: imdb_MovieLens.movies2actors
# Processed: imdb_MovieLens.movies2directors
# Processed: imdb_MovieLens.u2base
# Processed: imdb_MovieLens.users
# Processed: ccs.customers
# Processed: ccs.gasstations
# Processed: ccs.products
# Processed: ccs.transactions
# Processed: ccs.transactions_1k
# Processed: ccs.yearmonth
# Processed: financial.account
# Processed: financial.card
# Processed: financial.client
# Processed: financial.disp
# Processed: financial.district
# Processed: financial.loan
# Processed: financial.order
# Processed: financial.trans
# Processed: Countries.Data
# Processed: Countries.Metadata - Countries
# Processed: Countries.Metadata - Indicators
# Processed: Countries.target
# Processed: Mondial.Country2Continent
# Processed: Mondial.Country_Full
# Processed: Mondial.Independent_Borders
# Processed: Mondial.Independent_Countries
# Processed: Mondial.Named_Borders
# Processed: Mondial.Symmetric_Borders
# Processed: Mondial.borders
# Processed: Mondial.city
# Processed: Mondial.continent
# Processed: Mondial.country
# Processed: Mondial.desert
# Processed: Mondial.economy
# Processed: Mondial.encompasses
# Processed: Mondial.ethnicGroup
# Processed: Mondial.geo_desert
# Processed: Mondial.geo_estuary
# Processed: Mondial.geo_island
# Processed: Mondial.geo_lake
# Processed: Mondial.geo_mountain
# Processed: Mondial.geo_river
# Processed: Mondial.geo_sea
# Processed: Mondial.geo_source
# Processed: Mondial.isMember
# Processed: Mondial.island
# Processed: Mondial.islandIn
# Processed: Mondial.lake
# Processed: Mondial.language
# Processed: Mondial.located
# Processed: Mondial.locatedOn
# Processed: Mondial.mergesWith
# Processed: Mondial.mountain
# Processed: Mondial.mountainOnIsland
# Processed: Mondial.organization
# Processed: Mondial.politics
# Processed: Mondial.population
# Processed: Mondial.province
# Processed: Mondial.religion
# Processed: Mondial.river
# Processed: Mondial.sea
# Processed: Mondial.target
# Processed: legalActs.legalact_link
# Processed: legalActs.legalact_people
# Processed: legalActs.legalacts
# Processed: legalActs.people
# Processed: legalActs.scrapefix
# Processed: Mesh.circuit
# Processed: Mesh.circuit_hole
# Processed: Mesh.cont_loaded
# Processed: Mesh.element
# Processed: Mesh.equal
# Processed: Mesh.fixed
# Processed: Mesh.free
# Processed: Mesh.half_circuit
# Processed: Mesh.half_circuit_hole
# Processed: Mesh.llong
# Processed: Mesh.long_for_hole
# Processed: Mesh.mesh
# Processed: Mesh.mesh_test
# Processed: Mesh.mesh_test_Neg
# Processed: Mesh.neighbour_xy
# Processed: Mesh.neighbour_yz
# Processed: Mesh.neighbour_zx
# Processed: Mesh.nnumber
# Processed: Mesh.noload
# Processed: Mesh.notimportant
# Processed: Mesh.one_side_fixed
# Processed: Mesh.one_side_loaded
# Processed: Mesh.opposite
# Processed: Mesh.quarter_circuit
# Processed: Mesh.short_for_hole
# Processed: Mesh.sshort
# Processed: Mesh.two_side_fixed
# Processed: Mesh.two_side_loaded
# Processed: Mesh.usual
# Processed: trains.cars
# Processed: trains.trains
# Processed: Biodegradability.atom
# Processed: Biodegradability.bond
# Processed: Biodegradability.gmember
# Processed: Biodegradability.group
# Processed: Biodegradability.molecule
# Processed: Carcinogenesis.atom
# Processed: Carcinogenesis.canc
# Processed: Carcinogenesis.sbond_1
# Processed: Carcinogenesis.sbond_2
# Processed: Carcinogenesis.sbond_3
# Processed: Carcinogenesis.sbond_7
# Processed: Hepatitis_std.Bio
# Processed: Hepatitis_std.dispat
# Processed: Hepatitis_std.indis
# Processed: Hepatitis_std.inf
# Processed: Hepatitis_std.rel11
# Processed: Hepatitis_std.rel12
# Processed: Hepatitis_std.rel13
# Processed: PTE.active
# Processed: PTE.postestactive
# Processed: PTE.postestactive_Neg
# Processed: PTE.pte_active
# Processed: PTE.pte_alcohol
# Processed: PTE.pte_alkyl_halide
# Processed: PTE.pte_ames
# Processed: PTE.pte_amine
# Processed: PTE.pte_atm
# Processed: PTE.pte_atm_bond_count
# Processed: PTE.pte_atm_count
# Processed: PTE.pte_atm_max_charge
# Processed: PTE.pte_atm_min_charge
# Processed: PTE.pte_bond
# Processed: PTE.pte_bond_count
# Processed: PTE.pte_drug
# Processed: PTE.pte_ester
# Processed: PTE.pte_ether
# Processed: PTE.pte_five_ring
# Processed: PTE.pte_has_property
# Processed: PTE.pte_imine
# Processed: PTE.pte_ind
# Processed: PTE.pte_ketone
# Processed: PTE.pte_methoxy
# Processed: PTE.pte_methyl
# Processed: PTE.pte_mutagenic
# Processed: PTE.pte_nitro
# Processed: PTE.pte_non_ar_5c_ring
# Processed: PTE.pte_non_ar_6c_ring
# Processed: PTE.pte_non_ar_hetero_5_ring
# Processed: PTE.pte_non_ar_hetero_6_ring
# Processed: PTE.pte_number
# Processed: PTE.pte_phenol
# Processed: PTE.pte_six_ring
# Processed: PTE.pte_sulfide
# Processed: PTE.pte_sulfo
# Processed: PTE.pte_testactive
# Processed: PTE.pte_testactive_Neg
# Processed: classicmodels.customers
# Processed: classicmodels.employees
# Processed: classicmodels.offices
# Processed: classicmodels.orderdetails
# Processed: classicmodels.orders
# Processed: classicmodels.payments
# Processed: classicmodels.productlines
# Processed: classicmodels.products
# Processed: Credit.category
# Processed: Credit.charge
# Processed: Credit.corporation
# Processed: Credit.member
# Processed: Credit.payment
# Processed: Credit.provider
# Processed: Credit.region
# Processed: Credit.statement
# Processed: Credit.status
# Processed: ftp.product
# Processed: ftp.session
# Processed: northwind.Alphabetical list of products
# Processed: northwind.Categories
# Processed: northwind.Category Sales for 1997
# Processed: northwind.Current Product List
# Processed: northwind.Customer and Suppliers by City
# Processed: northwind.CustomerCustomerDemo
# Processed: northwind.CustomerDemographics
# Processed: northwind.Customers
# Processed: northwind.EmployeeTerritories
# Processed: northwind.Employees
# Processed: northwind.Invoices
# Processed: northwind.Order Details
# Processed: northwind.Order Details Extended
# Processed: northwind.Order Subtotals
# Processed: northwind.Orders
# Processed: northwind.Orders Qry
# Processed: northwind.Product Sales for 1997
# Processed: northwind.Products
# Processed: northwind.Products Above Average Price
# Processed: northwind.Products by Category
# Processed: northwind.Quarterly Orders
# Processed: northwind.Region
# Processed: northwind.Sales Totals by Amount
# Processed: northwind.Sales by Category
# Processed: northwind.Shippers
# Processed: northwind.Summary of Sales by Quarter
# Processed: northwind.Summary of Sales by Year
# Processed: northwind.Suppliers
# Processed: northwind.Territories
# Processed: sakila.actor
# Processed: sakila.address
# Processed: sakila.category
# Processed: sakila.city
# Processed: sakila.country
# Processed: sakila.customer
# Processed: sakila.film
# Processed: sakila.film_actor
# Processed: sakila.film_category
# Processed: sakila.film_text
# Processed: sakila.inventory
# Processed: sakila.language
# Processed: sakila.payment
# Processed: sakila.rental
# Processed: sakila.staff
# Processed: sakila.store
# Processed: SalesDB.Customers
# Processed: SalesDB.Employees
# Processed: SalesDB.Products
# Processed: SalesDB.Sales
# Processed: tpcds.call_center
# Processed: tpcds.catalog_page
# Processed: tpcds.catalog_returns
# Processed: tpcds.catalog_sales
# Processed: tpcds.customer
# Processed: tpcds.customer_address
# Processed: tpcds.customer_demographics
# Processed: tpcds.date_dim
# Processed: tpcds.household_demographics
# Processed: tpcds.income_band
# Processed: tpcds.inventory
# Processed: tpcds.item
# Processed: tpcds.promotion
# Processed: tpcds.reason
# Processed: tpcds.ship_mode
# Processed: tpcds.store
# Processed: tpcds.store_returns
# Processed: tpcds.store_sales
# Processed: tpcds.time_dim
# Processed: tpcds.warehouse
# Processed: tpcds.web_page
# Processed: tpcds.web_returns
# Processed: tpcds.web_sales
# Processed: tpcds.web_site
# Processed: AustralianFootball.match_stats
# Processed: AustralianFootball.matches
# Processed: AustralianFootball.players
# Processed: AustralianFootball.teams
# Processed: Hockey.AwardsCoaches
# Processed: Hockey.AwardsMisc
# Processed: Hockey.AwardsPlayers
# Processed: Hockey.Coaches
# Processed: Hockey.CombinedShutouts
# Processed: Hockey.Goalies
# Processed: Hockey.GoaliesSC
# Processed: Hockey.GoaliesShootout
# Processed: Hockey.HOF
# Processed: Hockey.Master
# Processed: Hockey.Scoring
# Processed: Hockey.ScoringSC
# Processed: Hockey.ScoringShootout
# Processed: Hockey.ScoringSup
# Processed: Hockey.SeriesPost
# Processed: Hockey.TeamSplits
# Processed: Hockey.TeamVsTeam
# Processed: Hockey.Teams
# Processed: Hockey.TeamsHalf
# Processed: Hockey.TeamsPost
# Processed: Hockey.TeamsSC
# Processed: Hockey.abbrev
# Processed: lahman_2014.allstarfull
# Processed: lahman_2014.appearances
# Processed: lahman_2014.awardsmanagers
# Processed: lahman_2014.awardsplayers
# Processed: lahman_2014.awardssharemanagers
# Processed: lahman_2014.awardsshareplayers
# Processed: lahman_2014.batting
# Processed: lahman_2014.battingpost
# Processed: lahman_2014.els_teamnames
# Processed: lahman_2014.fielding
# Processed: lahman_2014.fieldingof
# Processed: lahman_2014.fieldingpost
# Processed: lahman_2014.halloffame
# Processed: lahman_2014.managers
# Processed: lahman_2014.managershalf
# Processed: lahman_2014.pitching
# Processed: lahman_2014.pitchingpost
# Processed: lahman_2014.players
# Processed: lahman_2014.salaries
# Processed: lahman_2014.schools
# Processed: lahman_2014.schoolsplayers
# Processed: lahman_2014.seriespost
# Processed: lahman_2014.teams
# Processed: lahman_2014.teamsfranchises
# Processed: lahman_2014.teamshalf
# Table information for all tables in selected databases has been saved to all_selected_databases_info.xlsx
# Total tables processed: 331
#
# Unique values in the 'area' column:
# ['Education' 'Entertainment' 'Finance' 'Geography' 'Government' 'Industry'
#  'Logistic' 'Medicine' 'Retail' 'Sport']
